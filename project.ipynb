# %% [markdown]
# # Prepare Dataset

# %%
import csv
import networkx as nx
import numpy as np
from tqdm import tqdm

# %%
# prepare dataset

f = open('train.csv', 'r', encoding='utf-8')
reader = csv.reader(f)
trains = []
for line in reader:
    trains.append(line)
f.close()    
print("trains", len(trains))

f = open('node_ingredient.txt', 'r', encoding='utf-8')
reader = csv.reader(f)
nodes = []
for line in reader:
    nodes.append(line)
f.close()    
print("nodes", len(nodes))

f = open('validation_classification_question.csv', 'r', encoding='utf-8')
reader = csv.reader(f)
val_cls_q = []
for line in reader:
    val_cls_q.append(line)
f.close()
print("val_cls_q", len(val_cls_q))

f = open('validation_classification_answer.csv', 'r', encoding='utf-8')
reader = csv.reader(f)
val_cls_a = []
for line in reader:
    val_cls_a.append(line)
f.close()
print("val_cls_a", len(val_cls_a))

f = open('validation_completion_question.csv', 'r', encoding='utf-8')
reader = csv.reader(f)
val_cpt_q = []
for line in reader:
    val_cpt_q.append(line)
f.close()
print("val_cpt_q", len(val_cpt_q))

f = open('validation_completion_answer.csv', 'r', encoding='utf-8')
reader = csv.reader(f)
val_cpt_a = []
for line in reader:
    val_cpt_a.append(line)
f.close()
print("val_cpt_a", len(val_cpt_a))
# Out:
# trains 23547
# nodes 6714
# val_cls_q 7848
# val_cls_a 7848
# val_cpt_q 7848
# val_cpt_a 7848

# %%
# make graph of ingredients
G = nx.Graph()
for i in range(len(nodes)):
    G.add_node(str(i))
    
print(G.number_of_nodes())

for data in trains:
    for i in range(len(data) - 2):
        for j in range(i+1, len(data) - 1):
            if G.has_edge(data[i], data[j]):
                G[data[i]][data[j]]['weight'] += 1
            else:
                G.add_edge(data[i], data[j], weight=1)

print(G.number_of_edges())
# Out:
# 6714
# 355816

# %% [markdown]
# # Completion Task

# %% [markdown]
# ### Method 1

# %%
# completion task : find neighbors of largest weight
# large weight means high probability of being in the same recipe
cpt_answers = []
for data in tqdm(val_cpt_q):
#     print(data)
    weight_dict = {}
    for node in data:
        for adv, w in G.adj[node].items():
            if adv in weight_dict.keys():
                weight_dict[adv] += w['weight']
            else:
                weight_dict[adv] = w['weight']
    for node in data:
        if node in weight_dict.keys():
            del weight_dict[node]
    
    weight_dict = sorted(weight_dict.items(), key=(lambda x: x[1]), reverse=True)
    
#     print(weight_dict)

    cpt_answers.append(weight_dict[0][0])
# Out:
# 100%|███████████████████████████████████████| 7848/7848 [01:29<00:00, 87.89it/s]

# %%
acc = 0
for i in range(len(cpt_answers)):
    if cpt_answers[i] == val_cpt_a[i][0]:
        acc += 1
print(acc / len(cpt_answers) * 100)
# Out:
# 6.167176350662589

# %% [markdown]
# ### Method 2

# %%
# completion task : find neighbors of largest weight (but consider frequency)
# more frequently used ingredient -> not important? (ex. salt)
freq_dict = {}
for data in trains:
    for node in data[0:-1]:
        if node in freq_dict.keys():
            freq_dict[node] += 1
        else:
            freq_dict[node] = 1

for k,v in freq_dict.items():
    print(nodes[int(k)], v)
# Out:
# ['pepper'] 2631
# ['purple onion'] 1134
# ['grape tomatoes'] 133
# ['feta cheese crumbles'] 212
# ['garbanzo beans'] 91
# ['seasoning'] 83
# ['black olives'] 135
# ['romaine lettuce'] 168
# ['garlic'] 4329
# ['grilled chicken breasts'] 3
# ['salt'] 10683
# ['eggs'] 2007
# ['cooking oil'] 276
# ['garlic powder'] 857
# ['chicken livers'] 40
# ['green chilies'] 452
# ['mayonaise'] 460
# ['soy sauce'] 1928
# ['yellow onion'] 698
# ['butter'] 2809
# ['vegetable oil'] 2594
# ['wheat'] 17
# ['water'] 4347
# ['passata'] 11
# ['bay leaf'] 486
# ['cayenne pepper'] 890
# ['black pepper'] 1580
# ['boneless chicken skinless thigh'] 214
# ['cornflour'] 51
# ['garlic paste'] 157
# ['milk'] 1323
# ['chili powder'] 1181
# ['shallots'] 861
# ['double cream'] 26
# ['oil'] 1170
# ['ground cumin'] 1637
# ['garam masala'] 557
# ['onions'] 4685
# ['natural yogurt'] 10
# ['lemon juice'] 845
# ['plain flour'] 87
# ['sugar'] 3759
# ['powdered sugar'] 293
# ['fresh ginger root'] 196
# ['ground ginger'] 407
# ['ground cinnamon'] 744
# ['baking powder'] 999
# ['vanilla extract'] 782
# ['skirt steak'] 48
# ['chorizo sausage'] 61
# ['sea salt'] 536
# ['jalapeno chilies'] 1034
# ['white vinegar'] 324
# ['medium shrimp'] 289
# ['olive oil'] 4764
# ['chopped cilantro'] 467
# ['flat leaf parsley'] 667
# ['flour'] 778
# ['pistachio nuts'] 15
# ['white almond bark'] 1
# ['almond extract'] 99
# ['dried cranberries'] 32
# ['pork'] 179
# ['chopped cilantro fresh'] 998
# ['fresh pineapple'] 31
# ['ground black pepper'] 2859
# ['lime'] 822
# ['cheddar cheese'] 266
# ['poblano peppers'] 72
# ['iceberg lettuce'] 89
# ['corn tortillas'] 560
# ['chopped tomatoes'] 181
# ['kosher salt'] 1861
# ['extra-virgin olive oil'] 1658
# ['fresh basil'] 709
# ['Italian parsley leaves'] 69
# ['trout fillet'] 6
# ['hot red pepper flakes'] 98
# ['garlic cloves'] 3713
# ['walnuts'] 65
# ['fresh lemon juice'] 985
# ['fine sea salt'] 156
# ['chipotle chile'] 90
# ['fresh cilantro'] 476
# ['avocado'] 732
# ['flank steak'] 152
# ['plum tomatoes'] 507
# ['lime juice'] 638
# ['crushed red pepper flakes'] 287
# ['ground coriander'] 458
# ['spinach'] 221
# ['red lentils'] 64
# ['red chili peppers'] 409
# ['naan'] 21
# ['vegetable stock'] 105
# ['tumeric'] 468
# ['sweet potatoes'] 269
# ['tomatoes'] 1808
# ['fresh lime juice'] 795
# ['chicken broth'] 894
# ['cooked rice'] 249
# ['chicken breasts'] 478
# ['corn starch'] 1049
# ['garlic chili sauce'] 74
# ['yellow squash'] 71
# ['sliced green onions'] 258
# ['broccolini'] 14
# ['red bell pepper'] 1148
# ['chopped fresh mint'] 188
# ['thai basil'] 98
# ['pork loin'] 39
# ['beansprouts'] 260
# ['hoisin sauce'] 250
# ['rice noodles'] 152
# ['creamy peanut butter'] 54
# ['roasted peanuts'] 95
# ['rice'] 309
# ['spicy brown mustard'] 16
# ['low-fat mayonnaise'] 12
# ['baking potatoes'] 128
# ['lemon zest'] 159
# ['marinara sauce'] 140
# ['linguine'] 149
# ['olives'] 101
# ['capers'] 311
# ['lo mein noodles'] 20
# ['dark soy sauce'] 170
# ['light soy sauce'] 193
# ['oyster sauce'] 257
# ['cabbage'] 243
# ['sesame oil'] 1035
# ['chives'] 116
# ['dried black mushrooms'] 7
# ['peanuts'] 233
# ['sherry'] 52
# ['grated parmesan cheese'] 1136
# ['spaghetti'] 204
# ['cooked chicken'] 177
# ['heavy cream'] 674
# ['all-purpose flour'] 2739
# ['sliced mushrooms'] 154
# ['ground pork'] 296
# ['molasses'] 72
# ['egg roll wrappers'] 30
# ['sweet and sour sauce'] 6
# ['green bell pepper'] 669
# ['shredded cabbage'] 61
# ['carrots'] 1635
# ['cheese'] 281
# ['large eggs'] 1755
# ['breakfast sausages'] 22
# ['flour tortillas'] 537
# ['dried oregano'] 987
# ['paprika'] 787
# ['onion powder'] 302
# ['chinese chives'] 24
# ['turnips'] 64
# ['lime wedges'] 285
# ['fish sauce'] 755
# ['chile powder'] 67
# ['firm tofu'] 112
# ['sliced chicken'] 3
# ['green papaya'] 15
# ['tamarind paste'] 50
# ['palm sugar'] 73
# ['creole seasoning'] 155
# ['shrimp'] 523
# ['jambalaya rice mix'] 2
# ['worcestershire sauce'] 396
# ['hot pepper sauce'] 181
# ['diced tomatoes'] 985
# ['Johnsonville Andouille Dinner Sausage'] 1
# ['parsley'] 218
# ['great northern beans'] 30
# ['bread slices'] 31
# ['sage leaves'] 61
# ['star anise'] 137
# ['chinese five-spice powder'] 148
# ['crushed garlic'] 64
# ['chicken thighs'] 186
# ['ham hock'] 26
# ['rib'] 36
# ['collard greens'] 98
# ['bay leaves'] 647
# ['large garlic cloves'] 527
# ['apple cider'] 26
# ['freshly ground pepper'] 555
# ['chicken stock'] 635
# ['light brown sugar'] 250
# ['italian seasoning'] 231
# ['pepperoni'] 34
# ['mozzarella cheese'] 285
# ['hoagie rolls'] 11
# ['Oscar Mayer Deli Fresh Smoked Ham'] 1
# ['giardiniera'] 7
# ['salami'] 26
# ['turbinado'] 31
# ['ice cubes'] 82
# ['club soda'] 31
# ['white rum'] 10
# ['chicken breast halves'] 88
# ['chopped onion'] 723
# ['lettuce leaves'] 110
# ['grapefruit juice'] 8
# ['lemon olive oil'] 1
# ['fennel bulb'] 126
# ['crawfish'] 72
# ['crab boil'] 8
# ['cream cheese'] 335
# ['old bay seasoning'] 60
# ['green onions'] 1834
# ['glass noodles'] 19
# ['sirloin'] 14
# ['mirin'] 305
# ['shiitake'] 194
# ['sake'] 201
# ['napa cabbage'] 122
# ['corn oil'] 69
# ['low sodium soy sauce'] 245
# ['ground red pepper'] 328
# ['monterey jack'] 134
# ['whipping cream'] 359
# ['hot sauce'] 389
# ['quickcooking grits'] 45
# ['extra sharp cheddar cheese'] 35
# ['finely chopped onion'] 257
# ['basil'] 178
# ['dry white wine'] 716
# ['crushed red pepper'] 485
# ['mussels'] 107
# ['pesto'] 78
# ['white wine'] 208
# ['lemon'] 704
# ['salmon fillets'] 102
# ['curry powder'] 402
# ['unsalted butter'] 1610
# ['low sodium beef broth'] 15
# ['pickapeppa sauce'] 2
# ['cold water'] 310
# ['bread crumbs'] 194
# ['curry'] 34
# ['fresh thyme'] 209
# ['allspice'] 77
# ['ground beef'] 523
# ['chopped walnuts'] 73
# ['matcha green tea powder'] 5
# ['white sugar'] 634
# ['melted butter'] 151
# ['leeks'] 244
# ['low-fat sour cream'] 40
# ['1% low-fat milk'] 122
# ['cooking spray'] 891
# ['yukon gold potatoes'] 131
# ['peanut sauce'] 13
# ['lemongrass'] 233
# ['fresh ginger'] 891
# ['tamari soy sauce'] 47
# ['unsweetened coconut milk'] 121
# ['dry sherry'] 150
# ['golden brown sugar'] 53
# ['boiling water'] 190
# ['spareribs'] 6
# ['ghee'] 182
# ['tomato paste'] 702
# ['cumin seed'] 556
# ['chile pepper'] 191
# ['ground turmeric'] 557
# ['chicken legs'] 71
# ['fresh rosemary'] 262
# ['pappardelle'] 5
# ['crushed tomatoes'] 274
# ['boneless pork loin'] 34
# ['coconut milk'] 524
# ['extra firm tofu'] 76
# ['eggplant'] 316
# ['red curry paste'] 63
# ['vanilla'] 184
# ['large egg yolks'] 334
# ['gingersnap'] 3
# ['ground nutmeg'] 366
# ['marshmallow creme'] 10
# ['orange juice concentrate'] 12
# ['toasted pecans'] 19
# ['maple syrup'] 68
# ['pumpkin purée'] 13
# ['membrillo'] 1
# ['manchego cheese'] 35
# ['sourdough'] 10
# ['serrano ham'] 20
# ['dijon mustard'] 311
# ['whole nutmegs'] 9
# ['ground cloves'] 235
# ['ground cardamom'] 138
# ['balsamic vinegar'] 368
# ['red pepper'] 272
# ['Italian bread'] 72
# ['saffron'] 117
# ['warm water'] 325
# ['chickpeas'] 243
# ['fresh parsley'] 933
# ['harissa'] 29
# ['ground pepper'] 215
# ['couscous'] 115
# ['preserved lemon'] 47
# ['fat'] 62
# ['fat skimmed chicken broth'] 51
# ['cayenne'] 279
# ['pitted kalamata olives'] 121
# ['sweetened condensed milk'] 172
# ['ice'] 68
# ['espresso'] 13
# ['Fuyu persimmons'] 2
# ['foie gras'] 8
# ['white bread'] 87
# ['egg bread'] 3
# ['sherry vinegar'] 100
# ['demi-glace'] 3
# ['watercress'] 64
# ['Madeira'] 18
# ['large shrimp'] 247
# ['baby spinach leaves'] 65
# ['chopped garlic'] 209
# ['barley'] 4
# ['starchy potatoes'] 2
# ['grated nutmeg'] 142
# ['steak'] 35
# ['sirloin tip roast'] 4
# ['coarse salt'] 341
# ['buttermilk'] 503
# ['vinegar'] 196
# ['finely chopped fresh parsley'] 56
# ['caul fat'] 1
# ['kahlúa'] 10
# ['instant espresso powder'] 37
# ['heavy whipping cream'] 122
# ['whole milk'] 466
# ['cauliflower'] 118
# ['potatoes'] 606
# ['basmati rice'] 191
# ['scallions'] 1087
# ['cumin'] 581
# ['shredded carrots'] 95
# ['tomato sauce'] 518
# ['vegetable oil cooking spray'] 153
# ['part-skim mozzarella cheese'] 133
# ['english muffins', ' split and toasted'] 2
# ['chopped green bell pepper'] 151
# ['minced garlic'] 986
# ['boneless chop pork'] 19
# ['red wine vinegar'] 441
# ['pearl barley'] 21
# ['slivered almonds'] 95
# ['raisins'] 280
# ['chopped celery'] 257
# ['minced onion'] 121
# ['cod'] 24
# ['dry bread crumbs'] 170
# ['mustard powder'] 33
# ['vegetable broth'] 236
# ['black beans'] 526
# ['frozen corn'] 96
# ['quinoa'] 67
# ['duck'] 35
# ['brown sugar'] 898
# ['orange'] 195
# ['sauce'] 282
# ['dried mint flakes'] 22
# ['penne rigate'] 14
# ['feta cheese'] 173
# ['ground lamb'] 79
# ['ras el hanout'] 23
# ['large egg whites'] 270
# ['crumbled blue cheese'] 20
# ['2% reduced-fat milk'] 44
# ['sausages'] 112
# ['smoked streaky bacon'] 2
# ['crusty bread'] 21
# ['baby potatoes'] 11
# ['piloncillo'] 7
# ['ground allspice'] 210
# ['hibiscus'] 2
# ['cinnamon sticks'] 378
# ['dried thyme'] 486
# ['red beans'] 39
# ['lime zest'] 80
# ['skinless chicken thighs'] 5
# ['chipotles in adobo'] 124
# ['cilantro leaves'] 703
# ['instant white rice'] 4
# ['mixed spice'] 25
# ['demerara sugar'] 5
# ['fruit'] 23
# ['dried currants'] 62
# ['frozen pastry puff sheets'] 59
# ['egg whites'] 259
# ['creole style seasoning'] 6
# ['condensed cheddar cheese soup'] 5
# ['refried beans'] 159
# ['grated jack cheese'] 34
# ['sour cream'] 889
# ['bacon slices'] 122
# ['asparagus'] 135
# ['lard'] 93
# ['fresh fava bean'] 9
# ['pecorino romano cheese'] 93
# ['italian sausage'] 71
# ['pasta sheets'] 4
# ['curry paste'] 64
# ['Flora Cuisine'] 5
# ['ginger'] 1053
# ['low-fat natural yogurt'] 2
# ['spinach leaves'] 47
# ['tortilla chips'] 164
# ['radishes'] 181
# ['canola oil'] 728
# ['bone-in chicken breasts'] 15
# ['dried chile peppers'] 5
# ['white hominy'] 32
# ['granulated sugar'] 502
# ['frozen whipped topping'] 10
# ['instant butterscotch pudding mix'] 1
# ['graham cracker crumbs'] 21
# ['chocolate instant pudding'] 6
# ['kalamata'] 124
# ['fennel seeds'] 215
# ['moong dal'] 14
# ['green mango'] 7
# ['capsicum'] 29
# ['toasted sesame oil'] 211
# ['dried shiitake mushrooms'] 64
# ['gari'] 30
# ['tofu'] 79
# ['short-grain rice'] 35
# ['vine ripened tomatoes'] 19
# ['Turkish bay leaves'] 14
# ['semolina'] 33
# ['celery ribs'] 320
# ['dried chickpeas'] 14
# ['peanut oil'] 376
# ['organic chicken'] 6
# ['clove'] 353
# ['calimyrna figs'] 11
# ['plain whole-milk yogurt'] 27
# ['honey'] 761
# ['unflavored gelatin'] 69
# ['orange blossom honey'] 8
# ['zinfandel'] 6
# ['anise'] 40
# ['yellow corn meal'] 185
# ['Corn Flakes Cereal'] 5
# ['catfish fillets'] 59
# ['coleslaw'] 13
# ['chili paste'] 75
# ['asian pear'] 23
# ['red pepper flakes'] 388
# ['kiwi'] 16
# ['chees fresco queso'] 21
# ['salsa'] 571
# ['swiss chard'] 61
# ['veal cutlets'] 11
# ['mushrooms'] 347
# ['low salt chicken broth'] 227
# ['pasta'] 182
# ['garlic salt'] 146
# ['scallion greens'] 31
# ['wonton wrappers'] 100
# ['nonstick spray'] 33
# ['Sriracha'] 169
# ['peeled fresh ginger'] 345
# ['boneless skinless chicken breast halves'] 361
# ['green peas'] 115
# ['white rice'] 145
# ['clams'] 57
# ['hard-boiled egg'] 72
# ['artichoke hearts'] 82
# ['dry mustard'] 93
# ['frozen peas'] 222
# ['stuffing'] 11
# ['coriander powder'] 140
# ['maida flour'] 9
# ['grated Gruyère cheese'] 34
# ['whole peeled tomatoes'] 68
# ['shredded Monterey Jack cheese'] 192
# ['pickled jalapenos'] 14
# ['thai chile'] 132
# ['cucumber'] 454
# ['peppercorns'] 86
# ['refrigerated piecrusts'] 41
# ['herbs'] 52
# ['frozen peas and carrots'] 14
# ['low sodium chicken broth'] 202
# ['cream of chicken soup'] 51
# ['sweet onion'] 201
# ['pork shoulder roast'] 17
# ['taco sauce'] 38
# ['guacamole'] 112
# ['condiments'] 9
# ['salsa verde'] 83
# ['tortillas'] 134
# ['rose petals'] 2
# ['pistachios'] 39
# ['almonds'] 127
# ['Old El Paso Flour Tortillas'] 5
# ['taco seasoning mix'] 108
# ['beef rib short'] 40
# ['cranberry sauce'] 2
# ['beer'] 123
# ['chili sauce'] 96
# ['myzithra'] 2
# ['kefalotyri'] 6
# ['fresh dill'] 158
# ['phyllo'] 14
# ['yoghurt'] 156
# ['okra'] 150
# ['cracker crumbs'] 11
# ['crab meat'] 19
# ['Philadelphia Cream Cheese'] 12
# ['savoy cabbage'] 33
# ['orange liqueur'] 42
# ['confectioners sugar'] 222
# ['cream of tartar'] 97
# ['cake flour'] 109
# ['semi-sweet chocolate morsels'] 41
# ['ricotta cheese'] 207
# ['serrano'] 16
# ['white onion'] 415
# ['steel-cut oats'] 5
# ['sweet cherries'] 15
# ['hazelnuts'] 67
# ['hazelnut oil'] 3
# ['hamburger buns'] 31
# ['fire roasted diced tomatoes'] 9
# ['red kidnei beans', ' rins and drain'] 10
# ['sweet pepper'] 37
# ['andouille sausage'] 153
# ['wasabi paste'] 25
# ['Japanese soy sauce'] 18
# ['rice vinegar'] 683
# ['black sesame seeds'] 26
# ['fresh salmon'] 2
# ['dry red wine'] 195
# ['cremini mushrooms'] 83
# ['fat free less sodium beef broth'] 9
# ['hot water'] 212
# ['dried porcini mushrooms'] 59
# ['chopped fresh thyme'] 239
# ['green tomatoes'] 63
# ['creole mustard'] 33
# ['shrimp and crab boil seasoning'] 7
# ['prepared horseradish'] 41
# ['celery salt'] 30
# ['black peppercorns'] 260
# ['country ham'] 26
# ['butternut squash'] 100
# ['turnip greens'] 16
# ['apples'] 86
# ['frozen edamame beans'] 13
# ['seasoning salt'] 77
# ['whole kernel corn', ' drain'] 67
# ['kalonji'] 6
# ['instant yeast'] 40
# ['strong white bread flour'] 10
# ['fresh coriander'] 173
# ['sunflower oil'] 61
# ['salted butter'] 45
# ['tomatillos'] 199
# ['baking soda'] 533
# ['beef stock'] 87
# ['lean steak'] 2
# ['Guinness Lager'] 1
# ['dried rosemary'] 101
# ['rosemary leaves'] 12
# ['dark sesame oil'] 118
# ['lean ground pork'] 25
# ['chinese cabbage'] 38
# ['water chestnuts', ' drained and chopped'] 7
# ['dipping sauces'] 31
# ['pico de gallo'] 49
# ['chorizo'] 49
# ['cheese slices'] 14
# ['french bread'] 125
# ['kale'] 96
# ['guajillo'] 6
# ['boneless beef short ribs'] 4
# ['Mexican beer'] 17
# ['fresh spinach'] 138
# ['saffron threads'] 172
# ['shortening'] 127
# ['fat free less sodium chicken broth'] 275
# ['pears'] 65
# ['puff pastry'] 28
# ['light pancake syrup'] 6
# ['bone in chicken thighs'] 23
# ['apple cider vinegar'] 162
# ['coconut aminos'] 9
# ['mushroom powder'] 1
# ['fresh bay leaves'] 9
# ['kidney beans'] 99
# ['yellow bell pepper'] 173
# ['orzo pasta'] 25
# ['sticky rice'] 18
# ['white sesame seeds'] 43
# ['seaweed'] 33
# ['wasabi'] 20
# ['jumbo shrimp'] 39
# ['dried basil'] 342
# ['chopped almonds'] 28
# ['broccoli'] 123
# ['baby arugula'] 31
# ['boneless skinless chicken breasts'] 666
# ['tequila'] 91
# ['margarita mix'] 2
# ['grits'] 112
# ['corn syrup'] 35
# ['pecan halves'] 55
# ['crust'] 15
# ['whiskey'] 24
# ['blackberries'] 60
# ['active dry yeast'] 204
# ['superfine sugar'] 45
# ['fresh mint'] 244
# ['luke warm water'] 3
# ['coriander'] 265
# ['medjool date'] 14
# ['smoked paprika'] 198
# ['diced bell pepper'] 5
# ['cream'] 154
# ['red potato'] 125
# ['romaine lettuce leaves'] 23
# ['queso fresco'] 86
# ['pickled jalapeno peppers'] 5
# ['chile sauce'] 28
# ['crema mexicana'] 13
# ['reduced sodium soy sauce'] 88
# ['mustard oil'] 17
# ['cashew nuts'] 126
# ['kasuri methi'] 32
# ['tomato ketchup'] 40
# ['kashmiri chile'] 1
# ['red chile powder'] 12
# ['boneless chicken breast'] 92
# ['cinnamon'] 422
# ['ginger paste'] 69
# ['mace'] 57
# ['pecan pie'] 1
# ['chocolate morsels'] 13
# ['ricotta salata'] 14
# ['tahini'] 36
# ['liquid'] 42
# ['bacon'] 346
# ['safflower oil'] 21
# ['store bought low sodium chicken stock'] 20
# ['jam'] 17
# ['shredded cheddar cheese'] 455
# ['bamboo shoots'] 70
# ['jicama'] 55
# ['water chestnuts'] 113
# ['green beans'] 207
# ['diced celery'] 56
# ['dinner rolls'] 8
# ['shredded sharp cheddar cheese'] 109
# ['cauliflower flowerets'] 2
# ['boiling potatoes'] 57
# ['fenugreek seeds'] 39
# ['tuna steaks'] 23
# ['baby spinach'] 149
# ['goat cheese'] 96
# ['cherry tomatoes'] 239
# ['spices'] 109
# ['small red potato'] 47
# ['baby carrots'] 38
# ['shredded mozzarella cheese'] 274
# ['vidalia onion'] 68
# ['smoked gouda'] 13
# ['chicken wings'] 89
# ['ground white pepper'] 206
# ['cooked white rice'] 89
# ['celery'] 495
# ['baby bok choy'] 51
# ['organic sugar'] 4
# ['grapeseed oil'] 47
# ['whole grain thin spaghetti'] 1
# ['dried cherry'] 15
# ['straw mushrooms'] 23
# ['kaffir lime leaves'] 83
# ['galangal'] 54
# ['haricots verts'] 37
# ['vidalia'] 2
# ['wax beans'] 5
# ['cooked shrimp'] 47
# ['green chile'] 171
# ['crabmeat'] 48
# ['cardamom pods'] 85
# ['vegan margarine'] 6
# ['coriander seeds'] 226
# ['pork shoulder'] 83
# ['chicken'] 582
# ['fresh raspberries'] 59
# ['torn romain lettuc leav'] 1
# ['wish bone guacamol ranch dress'] 1
# ['frozen whole kernel corn'] 50
# ['pinenuts'] 205
# ['dry vermouth'] 29
# ['canned low sodium chicken broth'] 46
# ['skinless chicken breasts'] 33
# ['roasted salted cashews'] 3
# ['fresh lemon'] 15
# ['toasted sesame seeds'] 164
# ['plain yogurt'] 226
# ['paneer cheese'] 6
# ['lemon grass'] 60
# ['english cucumber'] 100
# ['seasoned rice wine vinegar'] 31
# ['Thai fish sauce'] 63
# ['light brown muscavado sugar'] 1
# ['white wine vinegar'] 196
# ['fillets'] 42
# ['cajun seasoning'] 222
# ['hominy'] 46
# ['oregano'] 251
# ['boneless center cut pork chops'] 2
# ['pork tenderloin'] 138
# ['shell-on shrimp'] 19
# ['chili pepper'] 82
# ['boneless skinless chicken'] 23
# ['steamed white rice'] 22
# ['caramel sauce'] 11
# ['seasoned bread crumbs'] 56
# ['frozen chopped spinach'] 116
# ['half & half'] 210
# ['penne pasta'] 115
# ['reduced sodium tamari'] 3
# ['sesame seeds'] 402
# ['bean threads'] 17
# ['sourdough baguette'] 7
# ['roasted red peppers'] 149
# ['bean paste'] 23
# ['chinese black bean'] 1
# ['cooking wine'] 37
# ['rock sugar'] 10
# ['green cardamom'] 50
# ['dried chile'] 29
# ['szechwan peppercorns'] 87
# ['beef'] 150
# ['liquorice'] 1
# ['brown cardamom'] 22
# ['daikon'] 82
# ['red radishes'] 5
# ['chili flakes'] 97
# ['granulated garlic'] 30
# ['margarine'] 116
# ['firmly packed brown sugar'] 56
# ['skim milk'] 51
# ['chopped pecans'] 173
# ['chili'] 116
# ['cider vinegar'] 194
# ['dressing'] 38
# ['salad'] 37
# ['tuna fillets'] 6
# ['zucchini'] 541
# ['polenta'] 100
# ['bell pepper'] 230
# ['olive oil cooking spray'] 19
# ['fresh basil leaves'] 293
# ['spring onions'] 254
# ['sweet chili sauce'] 70
# ['cauliflower florets'] 42
# ['Pillsbury™ Refrigerated Crescent Dinner Rolls'] 6
# ['refrigerated crescent rolls'] 17
# ['Old El Paso™ mild red enchilada sauce'] 1
# ['Mexican cheese blend'] 100
# ['red enchilada sauce'] 38
# ['fennel'] 51
# ['orange zest'] 95
# ['baguette'] 159
# ['bottled clam juice'] 28
# ['orange juice'] 208
# ['grated orange peel'] 59
# ['chili garlic paste'] 8
# ['natural peanut butter'] 12
# ['minced ginger'] 123
# ['ketchup'] 256
# ['chile paste'] 28
# ['grated orange'] 94
# ['pineapple juice'] 45
# ['fresh red chili'] 22
# ['masa harina'] 64
# ['crème fraîche'] 89
# ['double-acting baking powder'] 11
# ['dark rum'] 72
# ['duck breast halves'] 3
# ['vanilla lowfat yogurt'] 5
# ['sliced almonds'] 101
# ['mint leaves'] 159
# ['arugula'] 103
# ['roma tomatoes'] 143
# ['pesto sauce'] 20
# ['pizza crust'] 27
# ['lentils'] 54
# ['vermicelli noodles'] 11
# ['pickled carrots'] 9
# ['leaves'] 56
# ['white radish'] 4
# ['cream cheese', ' soften'] 84
# ['plantains'] 23
# ['white corn tortillas'] 16
# ['coconut sugar'] 25
# ['coconut oil'] 134
# ['grated lemon peel'] 115
# ['ciabatta'] 12
# ['summer squash'] 12
# ['fresh herbs'] 30
# ['juice'] 170
# ['dried kidney beans'] 11
# ['smoked ham hocks'] 34
# ['brie cheese'] 25
# ['prosciutto'] 168
# ['wheat germ'] 5
# ['granny smith apples'] 77
# ['vermicelli'] 28
# ['boneless rib eye steaks'] 6
# ['bird chile'] 36
# ['mini cucumbers'] 2
# ['cornmeal'] 206
# ['russet potatoes'] 167
# ['corn flour'] 39
# ['Italian seasoned breadcrumbs'] 18
# ['evaporated milk'] 112
# ['cheese ravioli'] 15
# ['golden raisins'] 142
# ['reduced sodium chicken broth'] 120
# ['coconut cream'] 41
# ['coconut flour'] 9
# ['hearts of palm'] 9
# ['cilantro'] 692
# ['flax seed meal'] 6
# ['chunky peanut butter'] 17
# ['slaw mix'] 32
# ['oven-ready lasagna noodles'] 24
# ['fat-free cottage cheese'] 11
# ['fettucine'] 90
# ['radicchio'] 39
# ['tea bags'] 31
# ['rosemary sprigs'] 67
# ['canned beef broth'] 13
# ['rubbed sage'] 33
# ['boiled ham'] 1
# ['provolone cheese'] 104
# ['genoa salami'] 18
# ['capicola'] 5
# ['italian style rolls'] 1
# ['dill'] 55
# ['greek yogurt'] 138
# ['cracked black pepper'] 248
# ['chocolate sauce'] 4
# ['quail'] 6
# ['dashi'] 70
# ['extra large eggs'] 21
# ['stock'] 53
# ['shiso'] 12
# ['caster'] 4
# ['dried bonito flakes'] 24
# ['dashi kombu'] 13
# ['white miso'] 48
# ['mixed greens'] 35
# ['branzino fillets'] 1
# ['barbecue sauce'] 77
# ['prepared pizza crust'] 3
# ['Sargento® Traditional Cut Shredded Mozzarella Cheese'] 1
# ['erythritol'] 1
# ['asparagus tips'] 4
# ['artichokes'] 48
# ['nutmeg'] 146
# ['fresh chives'] 62
# ['medium eggs'] 15
# ['ice water'] 99
# ['tuna'] 29
# ['portabello mushroom'] 44
# ['allspice berries'] 19
# ['tomatillo salsa'] 7
# ['ground chicken'] 61
# ['chipotle'] 15
# ['white sandwich bread'] 27
# ['louisiana hot sauce'] 4
# ['lemon cucumber'] 1
# ['Himalayan salt'] 9
# ['arame'] 1
# ['konbu'] 36
# ['plain breadcrumbs'] 9
# ['fresh mushrooms'] 164
# ['bok choy'] 77
# ['uncook medium shrimp', ' peel and devein'] 11
# ['snow peas'] 110
# ['catfish'] 14
# ['basil pesto sauce'] 29
# ['aioli'] 7
# ['mozzarella balls'] 4
# ['vegetables'] 125
# ['sun-dried tomatoes'] 95
# ['cocoa powder'] 31
# ['corn chips'] 20
# ['roasted tomatoes'] 37
# ['Mexican cheese'] 44
# ['enchilada sauce'] 173
# ['pasilla pepper'] 5
# ['corn'] 195
# ['chinese noodles'] 11
# ['condensed cream of mushroom soup'] 33
# ['fettuccine pasta'] 17
# ['soft fresh goat cheese'] 28
# ['chopped fresh sage'] 70
# ['red beets'] 8
# ['boiled eggs'] 7
# ['caster sugar'] 64
# ['sharp cheddar cheese'] 88
# ['chopped fresh chives'] 118
# ['bread flour'] 111
# ['pork ribs'] 15
# ['sesame salt'] 2
# ['ginger juice'] 6
# ['rice wine'] 121
# ['lasagne'] 5
# ['ricotta'] 57
# ['frozen spinach'] 33
# ['non-fat sour cream'] 79
# ['fat-free mayonnaise'] 15
# ['fat free cream cheese'] 10
# ['reduced fat swiss cheese'] 4
# ['sundried tomato paste'] 4
# ['cannellini beans'] 125
# ['roasted garlic'] 18
# ['dried tart cherries'] 13
# ['sheep’s milk cheese'] 2
# ['champagne vinegar'] 19
# ['duck fat'] 10
# ['squabs'] 3
# ['confit'] 7
# ['porcini'] 6
# ['sourdough loaf'] 3
# ['aged gouda'] 1
# ['soppressata'] 10
# ['fresh thyme leaves'] 129
# ['chopped parsley'] 198
# ['anchovy fillets'] 118
# ['lemon slices'] 46
# ['broccoli rabe'] 29
# ['chicken cutlets'] 25
# ['wheat flour'] 20
# ['wheat bran'] 6
# ['low-fat buttermilk'] 44
# ['whole wheat flour'] 94
# ['parmigiano reggiano cheese'] 218
# ['veal chops'] 5
# ['orzo'] 53
# ['masa'] 18
# ['ancho chile pepper'] 92
# ['coarse kosher salt'] 44
# ['oil cured olives'] 8
# ['pasta rotel'] 1
# ['fresh oregano'] 246
# ['parmesan cheese'] 355
# ['pasta water'] 8
# ['amchur'] 50
# ['chillies'] 66
# ['tamarind'] 21
# ['black salt'] 6
# ['brine-cured black olives'] 15
# ['thyme'] 200
# ['bourbon whiskey'] 117
# ['Tabasco Pepper Sauce'] 99
# ['grating cheese'] 41
# ['uncooked rigatoni'] 3
# ['fresh tomatoes'] 98
# ['long grain white rice'] 155
# ['chicken bouillon'] 44
# ['fish fillets'] 49
# ['shredded cheese'] 98
# ['shredded lettuce'] 100
# ['orange bell pepper'] 58
# ['red chili powder'] 140
# ['green bell pepper', ' slice'] 24
# ['golden delicious apples'] 23
# ['pepper flakes'] 41
# ['rice syrup'] 6
# ['buckwheat noodles'] 7
# ['bosc pears'] 17
# ['Gochujang base'] 74
# ['curry leaves'] 127
# ['urad dal'] 39
# ['Smithfield Ham'] 1
# ['vegetable shortening'] 78
# ['frozen blueberries'] 11
# ['peaches'] 161
# ['reduced fat milk'] 51
# ['thyme sprigs'] 127
# ['florets'] 26
# ['arborio rice'] 164
# ['gluten-free hoisin sauce'] 3
# ['edamame'] 22
# ['ground cayenne pepper'] 88
# ['toasted cashews'] 4
# ['butter lettuce'] 29
# ['short rib'] 17
# ['sambal ulek'] 35
# ['Shaoxing wine'] 154
# ['coconut vinegar'] 5
# ['lemon soda'] 1
# ['annatto oil'] 1
# ['Crystal Farms Butter'] 2
# ['Crystal Farms Shredded Gouda Cheese'] 1
# ['fresh marjoram'] 37
# ['crimini mushrooms'] 40
# ['boiling onions'] 10
# ['Oscar Mayer Bacon'] 1
# ["Campbell's Condensed Tomato Soup"] 2
# ['chunky salsa'] 39
# ['white pepper'] 248
# ['mustard'] 60
# ['pork belly'] 81
# ['brussels sprouts'] 19
# ['beef consomme'] 10
# ['beef bouillon granules'] 12
# ['tenderloin roast'] 4
# ['deli ham'] 11
# ['mild olive oil'] 12
# ['tapioca flour'] 31
# ['blanched almond flour'] 1
# ['parsnips'] 45
# ['beef roast'] 10
# ['Guinness Beer'] 12
# ['beef broth'] 224
# ['lamb shanks'] 30
# ['fatfree lowsodium chicken broth'] 11
# ['sweetened coconut flakes'] 41
# ['raisin bread'] 3
# ['bananas'] 128
# ['leg of lamb'] 50
# ['dried apricot'] 77
# ['pearl onions'] 52
# ['light margarine'] 1
# ['lemon pepper'] 25
# ['sliced black olives'] 87
# ['peeled shrimp'] 26
# ['malt vinegar'] 34
# ['gingerroot'] 70
# ['pork butt'] 46
# ['ground thyme'] 20
# ['basil leaves'] 165
# ['chutney'] 30
# ['canned chicken breast'] 1
# ['baking mix'] 11
# ['condensed cream of chicken soup'] 42
# ['poultry seasoning'] 32
# ['ginger ale'] 4
# ['navel oranges'] 36
# ['pasta sauce'] 141
# ['methi'] 10
# ['curds'] 36
# ['tandoori spices'] 11
# ['liquid aminos'] 6
# ['stevia'] 9
# ['brown lentils'] 15
# ['smoked sausage'] 82
# ['jasmine rice'] 90
# ['chicken drumsticks'] 54
# ['bone-in chicken breast halves'] 20
# ['dark brown sugar'] 176
# ['serrano chile'] 172
# ['wheat berries'] 2
# ['diced onions'] 148
# ['fresh parmesan cheese'] 175
# ['dried navy beans'] 5
# ['garnish'] 5
# ['parsley sprigs'] 94
# ['romano cheese'] 68
# ['roasted chestnuts'] 3
# ['all purpose unbleached flour'] 104
# ['taco seasoning'] 163
# ['stewed tomatoes'] 98
# ['chopped green chilies'] 36
# ['hash brown'] 4
# ['green pepper'] 231
# ['candy'] 9
# ['light corn syrup'] 97
# ['food paste color'] 1
# ['dried parsley'] 106
# ['varnish clams'] 8
# ['miso'] 30
# ['rice flour'] 74
# ['ravva'] 7
# ['asafoetida powder'] 23
# ['low-fat coconut milk'] 3
# ['Thai red curry paste'] 64
# ['soy marinade'] 1
# ['steamer'] 4
# ['chinese hot mustard'] 1
# ['chinese rice wine'] 75
# ['fenugreek'] 22
# ['fish'] 55
# ['asafetida'] 27
# ['coconut'] 104
# ['mustard seeds'] 183
# ['rigatoni'] 35
# ['rib roast'] 3
# ['gluten free blend'] 2
# ['bone in skinless chicken thigh'] 5
# ['salt and ground black pepper'] 131
# ['figs'] 20
# ['egg substitute'] 49
# ['beef brisket'] 46
# ['pepper sauce'] 14
# ['greek style plain yogurt'] 70
# ['dried minced onion'] 21
# ['asadero'] 12
# ['ground turkey'] 97
# ['beef stew'] 1
# ['mild curry powder'] 11
# ['pickling spices'] 11
# ['petite peas'] 3
# ['tostada shells'] 15
# ['chicken meat'] 39
# ['waxy potatoes'] 20
# ['pitted olives'] 19
# ['bow-tie pasta'] 68
# ['fresh peas'] 21
# ['white mushrooms'] 38
# ['penne'] 64
# ['leaf parsley'] 3
# ['garlic pepper seasoning'] 6
# ['Greek feta'] 2
# ['nectarines'] 19
# ['apricot preserves'] 13
# ['roast red peppers', ' drain'] 29
# ['sweet paprika'] 78
# ['pitted prunes'] 11
# ['Madras curry powder'] 23
# ['prawns'] 59
# ['teriyaki sauce'] 39
# ['stir fry vegetable blend'] 14
# ['medium egg noodles'] 12
# ['low-fat cottage cheese'] 15
# ['part-skim ricotta cheese'] 67
# ['whole wheat lasagna noodles'] 7
# ['shredded parmesan cheese'] 33
# ['red currant jelly'] 6
# ['toasted almonds'] 24
# ['amaretto'] 17
# ['spring mix'] 1
# ['burgers'] 4
# ['dried fig'] 19
# ["soft goat's cheese"] 9
# ['whole wheat english muffins'] 1
# ['fresh green bean'] 56
# ['egg yolks'] 306
# ['brewed coffee'] 25
# ['tart'] 4
# ['sea salt flakes'] 11
# ['chickpea flour'] 28
# ['apricots'] 19
# ['base'] 27
# ['grappa'] 6
# ['ham'] 142
# ['corn grits'] 10
# ['rolls'] 53
# ['black bean sauce'] 19
# ['beef tenderloin'] 36
# ['pinto beans'] 96
# ['sirloin tip'] 5
# ['marinade'] 51
# ['whole wheat tortillas'] 53
# ['low-fat soy milk'] 1
# ['nutritional yeast'] 18
# ['bagels'] 2
# ['marmite'] 6
# ['chicken bouillon granules'] 31
# ['fino sherry'] 2
# ['Maggi'] 13
# ['cooked ham'] 40
# ['Alfredo sauce'] 33
# ['Hatch Green Chiles'] 4
# ['jack'] 16
# ['bread'] 100
# ['panko breadcrumbs'] 88
# ['chicken fingers'] 27
# ['fresh leav spinach'] 34
# ['snappers'] 7
# ['red bell pepper', ' sliced'] 5
# ['1% low-fat cottage cheese'] 9
# ['fresh sage'] 27
# ['dry coconut'] 18
# ['green cabbage'] 108
# ['peanut butter'] 66
# ['hot pepper'] 43
# ['chili beans'] 15
# ['tenderloin'] 1
# ['rotisserie chicken'] 41
# ['beaten eggs'] 36
# ['crackers'] 24
# ['udon'] 26
# ['veggies'] 15
# ['broccoli florets'] 111
# ['noodles'] 125
# ['crystallized ginger'] 24
# ['quatre épices'] 3
# ['parmigiano-reggiano cheese'] 36
# ['gluten free soy sauce'] 8
# ['snails'] 3
# ['fine salt'] 17
# ['gruyere cheese'] 63
# ['baby beets'] 1
# ['salad dressing'] 35
# ['shrimp paste'] 34
# ['white beans'] 50
# ['bread crumb fresh'] 105
# ['cream of mushroom soup'] 22
# ['black-eyed peas'] 116
# ['long grain and wild rice mix'] 5
# ['whole wheat bread toasted'] 2
# ['cornbread'] 15
# ['onion soup'] 3
# ['sage'] 31
# ['ground chuck'] 32
# ['lamb chops'] 7
# ['gnocchi'] 24
# ['romana'] 1
# ['squid'] 50
# ['apple juice'] 29
# ['light sour cream'] 31
# ['elbow macaroni'] 62
# ['red wine'] 120
# ['fully cooked ham'] 6
# ['tomato purée'] 122
# ['white cheddar cheese'] 29
# ['whole milk ricotta cheese'] 29
# ['mascarpone'] 80
# ['vinaigrette dressing'] 5
# ['mandarin orange segments'] 4
# ['lettuce'] 105
# ['dark molasses'] 7
# ['bittersweet chocolate'] 73
# ['serrano peppers'] 64
# ['meat'] 87
# ['lean ground turkey'] 13
# ['pork loin chops'] 35
# ['ladyfingers'] 27
# ['unsweetened cocoa powder'] 154
# ['reduced fat cream cheese'] 7
# ['whipped topping'] 26
# ['instant espresso granules'] 4
# ['unsweetened chocolate'] 24
# ['rice vermicelli'] 58
# ['rice paper'] 41
# ['perilla'] 9
# ['Vietnamese coriander'] 13
# ['mint'] 103
# ['asian basil'] 1
# ['chile bean paste'] 3
# ['homemade chicken stock'] 24
# ['hot curry powder'] 6
# ['grated lemon zest'] 208
# ['cognac'] 53
# ['pastry cream'] 4
# ['Grand Marnier'] 19
# ['arrowroot powder'] 7
# ['gluten free corn tortillas'] 2
# ['gluten free cooking spray'] 1
# ['Hurst Family Harvest Chipotle Lime Black Bean Soup mix'] 1
# ['chipotle puree'] 2
# ['fresh turmeric'] 9
# ['white peppercorns'] 16
# ['wheels'] 6
# ['rye'] 2
# ['cooked brown rice'] 25
# ['cola soft drink'] 4
# ['Mexican oregano'] 61
# ['chipotle chile powder'] 25
# ['tahini paste'] 3
# ['green olives'] 113
# ['fresh curry leaves'] 43
# ['chuck'] 41
# ['dill weed'] 10
# ['nonfat ricotta cheese'] 21
# ['pork baby back ribs'] 12
# ['spiced rum'] 4
# ['jerk seasoning'] 5
# ['bbq sauce'] 16
# ['mexican chocolate'] 22
# ['shells'] 22
# ['achiote paste'] 5
# ['frozen orange juice concentrate'] 12
# ['cherries'] 23
# ['poblano chilies'] 18
# ['garlic juice'] 1
# ['turkey'] 33
# ['fresh lima beans'] 4
# ['cilantro sprigs'] 128
# ['corn kernels'] 159
# ['poblano chiles'] 92
# ['crusty sandwich rolls'] 3
# ['tilapia fillets'] 38
# ['sweet italian sausage'] 50
# ['dry pasta'] 9
# ['oyster mushrooms'] 20
# ['fat-trimmed beef flank steak'] 1
# ['salad oil'] 32
# ['prosecco'] 9
# ['bread dough'] 12
# ['jack cheese'] 71
# ['chiles'] 189
# ['self rising flour'] 111
# ['mashed potatoes'] 42
# ['leftover gravy'] 1
# ['cooked turkey'] 23
# ['turkey broth'] 4
# ['white cornmeal'] 41
# ['chinkiang vinegar'] 13
# ['firm silken tofu'] 5
# ['japanese eggplants'] 32
# ['relish'] 10
# ['fresca'] 5
# ['slaw'] 12
# ['fregola'] 4
# ['wild mushrooms'] 27
# ['abbamele'] 1
# ['fat free milk'] 78
# ['light mayonnaise'] 36
# ['pinot grigio'] 2
# ['mushroom caps'] 28
# ['liquid egg substitute'] 1
# ['chocolate candy bars'] 3
# ['pineapple'] 73
# ['dry roasted peanuts'] 35
# ['gai lan'] 23
# ['msg'] 15
# ['egg noodles'] 50
# ['self-rising cake flour'] 3
# ['pitted date'] 24
# ['golden syrup'] 19
# ['nori'] 58
# ['sushi rice'] 45
# ['paneer'] 68
# ['chaat masala'] 20
# ['soda'] 16
# ['gram flour'] 20
# ['button mushrooms'] 93
# ['boneless beef roast'] 3
# ['chipotle peppers'] 48
# ['spring roll wrappers'] 36
# ['ramen noodles'] 36
# ['boneless pork shoulder'] 42
# ['sesame'] 16
# ['Equal Sweetener'] 7
# ['soft-boiled egg'] 12
# ['pasilla chiles'] 15
# ['chicken pieces'] 51
# ['mulato chiles'] 5
# ['french rolls'] 5
# ['pumpkin seeds'] 24
# ['anise seed'] 25
# ['seeds'] 79
# ['truffle oil'] 12
# ['veal scallopini'] 2
# ['blanched almonds'] 52
# ['green cardamom pods'] 49
# ['poppy seeds'] 43
# ['raw cashews'] 21
# ['dough'] 65
# ['cake'] 26
# ['icing'] 6
# ['greens'] 52
# ['yeast'] 73
# ['bread yeast'] 1
# ['sea scallops'] 64
# ['biscuit baking mix'] 2
# ['old-fashioned oats'] 6
# ['ahi'] 3
# ['whole cranberry sauce'] 3
# ['rose water'] 10
# ['colby jack cheese'] 32
# ['taco shells'] 40
# ['unsalted cashews'] 17
# ['yardlong beans'] 12
# ['pure acai puree'] 3
# ['almond butter'] 12
# ['frozen banana'] 8
# ['champagne'] 17
# ['chambord'] 4
# ['pork chops'] 34
# ['curly endive'] 5
# ['diced tomatoes in juice'] 19
# ['plums'] 36
# ['stewing beef'] 17
# ['string beans'] 9
# ['lemon wedge'] 141
# ['porterhouse steaks'] 3
# ['dried tarragon leaves'] 29
# ['gooseberries'] 3
# ['fontina cheese'] 60
# ['parsley leaves'] 37
# ['vanilla cream'] 1
# ['vanilla wafers'] 21
# ['roasted sesame seeds'] 15
# ['turkey hot dogs'] 1
# ['dill pickles'] 19
# ['peas'] 128
# ['sausage casings'] 66
# ['plain low-fat yogurt'] 30
# ['baby portobello mushrooms'] 6
# ['lemon rind'] 39
# ['chanterelle'] 12
# ['dried pinto beans'] 21
# ['ground chipotle chile pepper'] 34
# ['long-grain rice'] 207
# ['veget soup mix'] 1
# ['chicken bones'] 5
# ['pork lard'] 7
# ['whole almonds'] 13
# ['marjoram'] 59
# ['chicken leg quarters'] 11
# ['orecchiette'] 27
# ['saltines'] 26
# ['corn bread'] 13
# ['pepper jack'] 47
# ['streaky bacon'] 3
# ['lardons'] 4
# ['cornichons'] 18
# ['rosemary'] 71
# ['wine'] 32
# ['brioche bread'] 2
# ['adobo sauce'] 53
# ['mango'] 155
# ['peeled deveined shrimp'] 7
# ['lillet'] 1
# ['soda water'] 9
# ['tiger prawn'] 14
# ['orange flower water'] 24
# ['ground almonds'] 29
# ['dates'] 34
# ['walnut halves'] 16
# ['food colouring'] 14
# ['condensed chicken broth'] 8
# ['and fat free half half'] 18
# ['unsalted chicken stock'] 10
# ['extra lean ground beef'] 20
# ['yellow curry paste'] 7
# ['fontina'] 18
# ['pizza shells'] 4
# ['xuxu'] 1
# ['green lentil'] 11
# ['lamb'] 44
# ['triple sec'] 25
# ['turbot'] 2
# ['pear tomatoes'] 6
# ['gaeta olives'] 4
# ['medium-grain rice'] 16
# ['fresh oregano leaves'] 30
# ['refrigerated pizza dough'] 20
# ['kimchi'] 67
# ['potato gnocchi'] 13
# ['olive oil spray'] 13
# ['lime rind'] 45
# ['pimenton'] 5
# ['beets'] 58
# ['lower sodium chicken broth'] 39
# ['guajillo chiles'] 36
# ['italian salad dressing'] 47
# ['angel hair'] 46
# ['ancho powder'] 47
# ['chili oil'] 60
# ['black vinegar'] 26
# ['sesame paste'] 11
# ['shanghai noodles'] 2
# ['tangerine'] 14
# ['pecans'] 79
# ['cherry preserves'] 4
# ['amaretto liqueur'] 6
# ['gelato'] 3
# ['whipped cream'] 59
# ['pimentos'] 85
# ['aleppo pepper'] 6
# ['peeled tomatoes'] 43
# ['vegetable oil spray'] 49
# ['fresh chevre'] 9
# ['plain dry bread crumb'] 11
# ['sugar pea'] 64
# ['canned chicken broth'] 12
# ['beef sirloin'] 20
# ['sliced shallots'] 13
# ['croissant dough'] 3
# ['baton'] 6
# ['applesauce'] 12
# ['red cabbage'] 75
# ['fish stock'] 37
# ['sturgeon fillets'] 1
# ['pickles'] 19
# ['glazed pecans'] 3
# ['clam juice'] 59
# ['self-rising cornmeal'] 19
# ['cottage cheese'] 58
# ['farmer cheese'] 11
# ['hungarian paprika'] 18
# ['halibut fillets'] 43
# ['fresh tarragon'] 75
# ['bulgur'] 18
# ['lamb shoulder'] 53
# ['tomatoes with juice'] 56
# ['cantaloupe'] 17
# ['honeydew melon'] 9
# ['fresh orange juice'] 127
# ['shrimp shells'] 9
# ['celery seed'] 46
# ['lasagna noodles'] 125
# ['chips'] 29
# ['boston butt'] 4
# ['smoked kielbasa'] 4
# ['hot dog bun'] 5
# ['all beef hot dogs'] 1
# ['sole fillet'] 4
# ['serrano chilies'] 41
# ['fresh onion'] 10
# ['white fleshed fish'] 6
# ['prepar salsa'] 18
# ['broth'] 60
# ['dhal'] 8
# ['chocolate bars'] 4
# ['coffee liqueur'] 17
# ['whitefish fillets'] 14
# ['daal'] 4
# ['idli'] 3
# ['flour for dusting'] 26
# ['pitted black olives'] 33
# ['rotini'] 38
# ['frozen mixed vegetables'] 10
# ['rolled oats'] 26
# ['buckwheat soba noodles'] 4
# ['wood ear mushrooms'] 16
# ['wasabi powder'] 14
# ['reduced fat coconut milk'] 6
# ['thai green curry paste'] 29
# ['vine tomatoes'] 9
# ['sprinkles'] 23
# ['seafood stock'] 9
# ['spanish rice'] 4
# ['shelled pistachios'] 10
# ['pure vanilla extract'] 85
# ['canned tomatoes'] 49
# ['asiago'] 57
# ['chinese red vinegar'] 1
# ['mushroom soy sauce'] 9
# ['pork spareribs'] 16
# ['vietnamese fish sauce'] 13
# ['pumpkin'] 34
# ['shoyu'] 13
# ['raspberries'] 50
# ['frozen mixed berries'] 8
# ['granola'] 6
# ['raw honey'] 11
# ['hanger steak'] 4
# ['grated coconut'] 47
# ['tapioca pearls'] 5
# ['pandanus leaf'] 14
# ['pork blade steaks'] 2
# ['single crust pie'] 7
# ['pastry'] 26
# ['light cream'] 32
# ['shredded swiss cheese'] 23
# ['angel food cake mix'] 1
# ['buttercream frosting'] 3
# ['calvados'] 18
# ['chestnut mushrooms'] 9
# ['beef rump steaks'] 2
# ['spring greens'] 2
# ['Country Crock® Spread'] 13
# ['condensed milk'] 41
# ['coffee'] 49
# ['slab bacon'] 4
# ['pig feet'] 4
# ['pork bones'] 5
# ['bulgur wheat'] 2
# ['watermelon'] 21
# ['tandoori paste'] 3
# ['boneless', ' skinless chicken breast'] 19
# ['cooked vermicelli'] 5
# ['reduced-fat sour cream'] 65
# ['ground chicken breast'] 13
# ['shredded reduced fat cheddar cheese'] 23
# ['frozen corn kernels'] 79
# ['pie dough'] 19
# ['orange marmalade'] 24
# ['buns'] 7
# ['hot Italian sausages'] 24
# ['boneless chicken breast halves'] 23
# ['bibb lettuce'] 18
# ['dried lentils'] 20
# ['duck stock'] 1
# ['freshly grated parmesan'] 63
# ['free range egg'] 14
# ['(10 oz.) frozen chopped spinach', ' thawed and squeezed dry'] 2
# ['phyllo dough'] 42
# ['ginger root'] 77
# ['garlic flakes'] 1
# ['masa dough'] 6
# ['corn husks'] 52
# ['grapefruit'] 12
# ['habanero pepper'] 19
# ['grated romano cheese'] 16
# ['pimento stuffed green olives'] 23
# ['soup'] 17
# ['butter beans'] 14
# ['ditalini pasta'] 9
# ['littleneck clams'] 38
# ['cotija'] 90
# ['frozen sweet corn'] 4
# ['whole wheat bread'] 12
# ['apricot nectar'] 1
# ['whole cloves'] 49
# ['curry sauce'] 10
# ['pappardelle pasta'] 5
# ['toast'] 11
# ['duck drippings'] 1
# ['pastry dough'] 19
# ['stilton'] 6
# ['fermented black beans'] 28
# ['softened butter'] 25
# ['grouper'] 10
# ['key lime juice'] 19
# ['pickle relish'] 17
# ['butter cooking spray'] 7
# ['sliced ham'] 16
# ['brandy'] 109
# ['vanilla beans'] 98
# ['coffee granules'] 20
# ['firmly packed light brown sugar'] 29
# ['lean ground beef'] 226
# ['shredded zucchini'] 8
# ['dried pasta'] 10
# ['diced tomatoes with garlic and onion'] 7
# ['semisweet chocolate'] 99
# ['agave nectar'] 54
# ['dark corn syrup'] 22
# ['lemon-lime soda'] 8
# ['frozen strawberries'] 8
# ['frozen limeade'] 6
# ['muenster cheese'] 4
# ['loin pork roast'] 14
# ['rocket leaves'] 29
# ['unsweetened apple juice'] 4
# ['whole allspice'] 16
# ['bonito flakes'] 23
# ['small red beans'] 8
# ['plain chocolate'] 1
# ['anise extract'] 6
# ['Poire Williams'] 2
# ['bartlett pears'] 10
# ['yolk'] 7
# ['gala apples'] 7
# ['vanilla ice cream'] 60
# ['mexican style 4 cheese blend'] 6
# ['quinces'] 8
# ['picante sauce'] 35
# ['ragu old world style tradit pasta sauc'] 1
# ['center cut loin pork chop'] 9
# ['pancake mix'] 4
# ['marsala wine'] 71
# ['tarragon'] 21
# ['chili bean sauce'] 8
# ['beef shank'] 15
# ['long beans'] 8
# ['1% low-fat buttermilk'] 1
# ['nonfat sweetened condensed milk'] 2
# ['bacon drippings'] 37
# ['salted dry roasted peanuts'] 5
# ['buffalo sauce'] 4
# ['blue cheese dressing'] 3
# ['nigella seeds'] 16
# ['asafoetida'] 43
# ['mexican chorizo'] 17
# ['chees fresh mozzarella'] 40
# ['curly kale'] 5
# ['togarashi'] 11
# ['toasted nori'] 8
# ['lumpia skins'] 5
# ['saltine crumbs'] 1
# ['red capsicum'] 10
# ['sprouts'] 8
# ['liquid smoke'] 24
# ['baby lima beans'] 22
# ['lemon lime beverage'] 1
# ['cachaca'] 36
# ['rum'] 37
# ['brown rice'] 120
# ['top sirloin steak'] 19
# ['clams', ' well scrub'] 3
# ['pork roast'] 22
# ['polish sausage'] 4
# ['breasts halves'] 2
# ['shrimp tails'] 5
# ['lump crab meat'] 70
# ['bay scallops'] 22
# ['capellini'] 8
# ['mild curry paste'] 5
# ['ranch salad dressing mix'] 2
# ['white corn'] 12
# ['fritos'] 7
# ['ponzu'] 12
# ['soba noodles'] 45
# ['chard'] 5
# ['pomegranate juice'] 12
# ['pomegranate seeds'] 16
# ['crushed ice'] 32
# ['lime slices'] 36
# ['caesar salad dressing'] 7
# ['croutons'] 22
# ['bacon bits'] 6
# ['strawberries'] 143
# ['salt pork'] 20
# ['Louisiana Hot Sauce'] 8
# ['panko'] 42
# ['pancetta'] 103
# ['hungarian sweet paprika'] 21
# ['coarse-grain salt'] 2
# ['country bread'] 28
# ['roasted hazelnuts'] 14
# ['meat bones'] 17
# ['beans'] 73
# ['nori flakes'] 1
# ['vegan mayonnaise'] 3
# ['condensed fiesta nacho cheese soup'] 3
# ['frozen tater tots'] 1
# ['frozen vegetables'] 6
# ['Old El Paso™ chopped green chiles'] 8
# ['green enchilada sauce'] 18
# ['Progresso Black Beans'] 1
# ['whitefish'] 26
# ["hellmann' or best food real mayonnais"] 20
# ['chicken feet'] 3
# ['ampalaya'] 3
# ['cactus leaf'] 1
# ['chili seasoning mix'] 1
# ['blood orange'] 7
# ['gran marnier'] 7
# ['frisee'] 12
# ['diced green chilies'] 57
# ['bacon fat'] 10
# ['pernod'] 14
# ['alcohol'] 2
# ['dark chocolate'] 27
# ['oysters'] 36
# ['evaporated skim milk'] 11
# ['ajwain'] 7
# ['banana peppers'] 11
# ['Splenda Brown Sugar Blend'] 2
# ['Anaheim chile'] 33
# ['liqueur'] 23
# ['aged balsamic vinegar'] 9
# ['Mexican vanilla extract'] 1
# ['low sodium vegetable broth'] 17
# ['asian fish sauce'] 79
# ['hot chili sauce'] 23
# ['bitter melon'] 3
# ['Knorr® Beef Bouillon'] 1
# ['winter squash'] 3
# ['cavolo nero'] 3
# ['toasted pine nuts'] 26
# ['OREO® Cookies'] 5
# ['kahlua'] 4
# ['store bought low sodium chicken broth'] 7
# ['beef stock cubes'] 19
# ['lean beef'] 12
# ['fleur de sel'] 13
# ['garden cress'] 1
# ['kirby cucumbers'] 17
# ['boneless chicken'] 23
# ['black'] 5
# ['tomato juice'] 44
# ['sugar syrup'] 5
# ['cooked chicken breasts'] 62
# ['long pasta'] 1
# ['linguini'] 5
# ['artichok heart marin'] 33
# ['instant rice'] 27
# ['beefsteak tomatoes'] 13
# ['pita bread'] 25
# ['cod fillets'] 24
# ['anchovy paste'] 44
# ['swordfish steaks'] 14
# ['chunky tomato salsa'] 3
# ['rhubarb'] 13
# ['dark beer'] 9
# ['sweet potatoes or yams'] 4
# ["I Can't Believe It's Not Butter!® Spread"] 12
# ['swiss cheese'] 35
# ['hothouse cucumber'] 26
# ['pork sausages'] 77
# ['low-fat milk'] 26
# ['shiitake mushroom caps'] 34
# ['mung bean sprouts'] 41
# ['white rice flour'] 12
# ['shredded coconut'] 31
# ['fresh mozzarella'] 56
# ['polenta prepar'] 4
# ['pan drippings'] 10
# ['boneless beef chuck roast'] 10
# ['juniper berries'] 13
# ['fresh chorizo'] 2
# ['nonfat cottage cheese'] 4
# ['drippings'] 6
# ['greek seasoning'] 28
# ['lily flowers'] 3
# ['soft tofu'] 34
# ['cloud ear fungus'] 1
# ['sirloin steak'] 42
# ['minced pork'] 26
# ['table salt'] 39
# ['blood orange juice'] 3
# ['papaya'] 16
# ['olive oil flavored cooking spray'] 30
# ['herb vinegar'] 3
# ['fresh prawn'] 4
# ['potato starch'] 37
# ['nonfat greek yogurt'] 16
# ['diced chicken'] 4
# ['extra sharp white cheddar cheese'] 6
# ['peasant bread'] 7
# ['green split peas'] 7
# ['brown basmati rice'] 8
# ['barley flakes'] 1
# ['no salt added chicken broth'] 5
# ['no-salt-added black beans'] 7
# ['soda bread'] 4
# ['light coconut milk'] 86
# ['hot dogs'] 10
# ['italian style stewed tomatoes'] 10
# ['crepes'] 13
# ['bottled balsamic vinaigrette'] 1
# ['scallops'] 22
# ['italian tomatoes'] 12
# ['beef smoked sausage'] 1
# ['fried rice'] 2
# ['rose essence'] 3
# ['khoa'] 6
# ['chana dal'] 11
# ['poppyseeds'] 1
# ['caviar'] 10
# ['whole wheat pizza crust'] 3
# ['pecorino cheese'] 27
# ['plum sauce'] 8
# ['won ton wrappers'] 30
# ['dumplings'] 18
# ['choy sum'] 9
# ['whole wheat pastry flour'] 21
# ['dried mixed herbs'] 8
# ['brine cured green olives'] 4
# ['yams'] 24
# ['red'] 5
# ['caraway seeds'] 52
# ['red miso'] 19
# ['pineapple juice concentrate'] 2
# ['whole chicken'] 26
# ['berries'] 20
# ['tomato salsa'] 27
# ['pizza sauce'] 47
# ['orange peel'] 22
# ['fresh chervil'] 11
# ['rioja'] 3
# ['pork shoulder butt'] 8
# ['smoked sweet Spanish paprika'] 9
# ['fatback'] 10
# ['spanish paprika'] 27
# ['hog casings'] 5
# ['red vermouth'] 5
# ['hot chili powder'] 15
# ['smoked bacon'] 18
# ['pork stew meat'] 6
# ['stew meat'] 8
# ['low sodium chicken stock'] 22
# ['suet'] 10
# ['oatmeal'] 4
# ['cooked barley'] 2
# ['pork blood'] 5
# ['maple sugar'] 6
# ['white peaches'] 2
# ['comino'] 1
# ['flounder fillets'] 11
# ['dried cascabel chile'] 1
# ['satsuma orange'] 1
# ['cane vinegar'] 6
# ['spaghettini'] 13
# ['mustard greens'] 34
# ['dry yeast'] 67
# ['whole okra'] 4
# ['loosely packed fresh basil leaves'] 16
# ['ripe olives'] 56
# ['turkey breast'] 19
# ['sub buns'] 5
# ['sliced cucumber'] 15
# ['Balsamico Bianco'] 5
# ['steamed rice'] 24
# ['veal for stew'] 4
# ['ranch dressing'] 42
# ['boneless chuck roast'] 12
# ['coke'] 2
# ['ravioli'] 11
# ['rub'] 12
# ['pizza doughs'] 71
# ['gorgonzola'] 20
# ['squash'] 19
# ['shichimi togarashi'] 10
# ['komatsuna'] 2
# ['kamaboko'] 1
# ['Tokyo negi'] 2
# ['panettone'] 5
# ['sambuca'] 3
# ['fat free frozen top whip'] 8
# ['pierogi'] 5
# ['dill tips'] 8
# ['buckwheat flour'] 12
# ['salmon roe'] 2
# ['smoked salmon'] 29
# ['calamansi juice'] 9
# ['black bean sauce with garlic'] 1
# ['frozen bread dough'] 7
# ['macaroni'] 24
# ['ground mustard'] 19
# ['refrigerated biscuits'] 9
# ['teas'] 21
# ['mini phyllo dough shells'] 3
# ['sweet potatoes & yams'] 6
# ['pie crust'] 34
# ['pumpkin pie spice'] 13
# ['minced beef'] 17
# ['rice bran oil'] 2
# ['dill seed'] 3
# ['black mustard seeds'] 63
# ['seitan'] 5
# ['fig jam'] 2
# ['cardamom'] 68
# ['chicken stock cubes'] 28
# ['redfish fillet'] 1
# ['ground turkey breast'] 22
# ['sofrito'] 2
# ['fat free yogurt'] 42
# ['instant espresso'] 4
# ['filet'] 25
# ['cooking liquid'] 2
# ['coconut juice'] 8
# ['pudding'] 3
# ['kumquats'] 10
# ['somen'] 3
# ['usukuchi soy sauce'] 1
# ['unsweetened shredded dried coconut'] 7
# ['cilantro root'] 13
# ['brown mushroom'] 3
# ['fresh parsley leaves'] 86
# ['sausage links'] 36
# ['rouille'] 3
# ['salad greens'] 30
# ['pastry flour'] 2
# ['tortellini'] 10
# ['fresh asparagus'] 24
# ['reduced fat alfredo sauce'] 3
# ['chuck roast'] 34
# ['goji berries'] 3
# ['black chicken'] 1
# ['rock salt'] 9
# ['wheat crackers'] 1
# ['potato chips'] 4
# ['baking spray'] 3
# ['lavender'] 3
# ['annatto powder'] 3
# ['chinese eggplants'] 8
# ['round steaks'] 16
# ['Tabasco Green Pepper Sauce'] 13
# ['fat free greek yogurt'] 4
# ['escarole'] 39
# ['spanish chorizo'] 36
# ['jamaican jerk spice'] 2
# ['organic vegetable broth'] 31
# ['pitas'] 26
# ['whole milk greek yogurt'] 4
# ['whole wheat pita'] 10
# ['deveined shrimp'] 30
# ['prego traditional italian sauce'] 4
# ['brown hash potato'] 4
# ['fresh blueberries'] 24
# ['nonfat milk'] 12
# ['soft-wheat flour'] 7
# ['bottle gourd'] 4
# ['palm oil'] 8
# ['dried shrimp'] 49
# ['passion fruit'] 5
# ['St Germain Liqueur'] 1
# ['cherry juice'] 2
# ['cocktail cherries'] 21
# ['oregano leaves'] 5
# ['ground veal'] 30
# ['mild Italian sausage'] 12
# ['port'] 12
# ['sandwich rolls'] 8
# ['white flour'] 21
# ['Zatarain’s Jambalaya Mix'] 1
# ['frozen peppers and onions'] 3
# ['ground roasted sichuan peppers'] 1
# ['potato flour'] 7
# ['almond flour'] 22
# ['sweet italian sausag links', ' cut into'] 3
# ['wide egg noodles'] 5
# ['sprite'] 7
# ['dried rice noodles'] 20
# ['orange pekoe tea'] 1
# ['boneless chicken thighs'] 29
# ['popcorn'] 3
# ['marrow bones'] 2
# ['corned beef'] 20
# ['savory'] 14
# ['Niçoise olives'] 19
# ['sea bass'] 9
# ['essence'] 12
# ['herbes de provence'] 37
# ['shredded pepper jack cheese'] 19
# ['gluten-free chicken stock'] 1
# ['wheat free soy sauce'] 2
# ['pineapple chunks'] 24
# ['yellow peppers'] 29
# ['citrus vinaigrette'] 1
# ['sliced salami'] 4
# ['farro'] 12
# ['curly leaf spinach'] 1
# ['roasted cashews'] 25
# ['epazote'] 24
# ['hass avocado'] 29
# ['garlic chives'] 12
# ['greater yam'] 2
# ['dried mushrooms'] 9
# ['dried prawns'] 1
# ['cured chorizo'] 1
# ['green peppercorns'] 13
# ['horseradish'] 25
# ['kielbasa'] 17
# ['knockwurst'] 3
# ['red delicious apples'] 4
# ['brats'] 5
# ['sauerkraut'] 17
# ['pinot blanc'] 1
# ['cinnamon rolls'] 3
# ['boneless pork shoulder roast'] 8
# ['branzino'] 5
# ['chocolate syrup'] 10
# ['cocoa'] 28
# ['canned black beans'] 36
# ['shredded extra sharp cheddar cheese'] 12
# ['pheasant'] 2
# ['venison'] 5
# ['rabbit'] 14
# ['frozen lima beans'] 3
# ['jelly'] 13
# ['bass'] 1
# ['gyoza wrappers'] 11
# ['veal stock'] 8
# ['veal'] 20
# ['turkey breakfast sausage'] 2
# ['bouillon cube'] 4
# ['tarama'] 2
# ['toasted nuts'] 1
# ['lower sodium soy sauce'] 39
# ['five-spice powder'] 12
# ['vanilla sugar'] 3
# ['splenda granular'] 1
# ['diced red onions'] 29
# ['applewood smoked bacon'] 8
# ['lemon peel'] 26
# ['coarse sea salt'] 38
# ['gluten free vanilla extract'] 1
# ['chopped hazelnuts'] 3
# ['dri leav thyme'] 19
# ['shredded mild cheddar cheese'] 12
# ['orange rind'] 21
# ['unsalted dry roast peanuts'] 32
# ['roasted pumpkin seeds'] 2
# ['flaked coconut'] 26
# ['unbaked pie crusts'] 9
# ['fat-free chicken broth'] 20
# ['fresh shiitake mushrooms'] 56
# ['lobster meat'] 7
# ['Irish whiskey'] 21
# ['ground oregano'] 12
# ['strawberry jam'] 3
# ['clotted cream'] 1
# ['vanilla essence'] 7
# ['glutinous rice flour'] 12
# ['sobrasada'] 1
# ['Pace Picante Sauce'] 3
# ['orange blossom extract'] 1
# ['silken tofu'] 26
# ['chocolate'] 17
# ['cold milk'] 9
# ['bacon grease'] 15
# ['dried sage'] 38
# ['wide rice noodles'] 7
# ['carrot greens'] 1
# ['file powder'] 27
# ['cranberries'] 16
# ['raw almond'] 9
# ['flat anchovy'] 3
# ['biscuits'] 35
# ['peaches in syrup'] 1
# ['sliced carrots'] 62
# ['rapeseed oil'] 10
# ['currant'] 26
# ['cookies'] 16
# ['oil packed anchovy fillets'] 3
# ['nonfat yogurt'] 29
# ['nonfat buttermilk'] 8
# ['low-fat yogurt'] 5
# ['non dairy milk'] 4
# ['pecan meal'] 1
# ['non-dairy margarine'] 1
# ['french baguette'] 25
# ['red serrano peppers'] 2
# ['frozen carrots'] 2
# ['honey glazed ham'] 2
# ['chitterlings'] 2
# ['baked ham'] 14
# ['steamed brown rice'] 2
# ['roast'] 16
# ['knorr cilantro minicub'] 1
# ['knorr parslei minicub'] 1
# ['mixed vegetables'] 15
# ['extra wide egg noodles'] 1
# ['instant coffee'] 11
# ['chocolate wafer cookies'] 2
# ['yellow lentils'] 6
# ['large tomato'] 4
# ['onion salt'] 7
# ['lager'] 7
# ['beef demi-glace'] 3
# ['mung beans'] 19
# ['piecrust'] 7
# ['lemon extract'] 16
# ['smoked ham'] 8
# ['Quinoa Flour'] 3
# ['spelt flour'] 4
# ['date sugar'] 1
# ['fine granulated sugar'] 3
# ['bicarbonate of soda'] 12
# ['stuffing mix'] 3
# ['whole wheat spaghetti'] 17
# ['fideos'] 5
# ['lima beans'] 20
# ['coconut extract'] 12
# ['whole grain mustard'] 19
# ['powdered milk'] 21
# ['heirloom tomatoes'] 27
# ['bucatini'] 10
# ['soybean paste'] 10
# ['sun-dried tomatoes in oil'] 23
# ['seedless red grapes'] 14
# ['mantou'] 1
# ['clear honey'] 15
# ['harissa paste'] 12
# ['Biryani Masala'] 5
# ['gravy'] 17
# ['fresh tuna steaks'] 4
# ['ground sausage'] 4
# ['pita pockets'] 2
# ['worcestershire sauce low sodium'] 1
# ['Velveeta'] 20
# ['watercress leaves'] 4
# ['onion tops'] 23
# ['canola'] 20
# ['dark chicken stock'] 1
# ['duck breasts'] 16
# ['black tea'] 9
# ['cream sweeten whip'] 24
# ['small capers', ' rins and drain'] 2
# ['crema mexican'] 19
# ['apple juice concentrate'] 4
# ['clarified butter'] 29
# ['sole'] 2
# ['gremolata'] 2
# ['bouquet'] 3
# ['garlic puree'] 8
# ['pekin duck breast halves'] 1
# ['stolichnaya'] 1
# ['vodka'] 43
# ['pepperocini'] 2
# ['small eggs'] 2
# ['wonton skins'] 6
# ['sweet rice wine'] 2
# ['ox tongue'] 2
# ['parsley flakes'] 28
# ['granulated white sugar'] 8
# ['cherry peppers'] 4
# ['dandelion'] 1
# ['pink grapefruit'] 7
# ['pink grapefruit juice'] 4
# ['low-fat vanilla ice cream'] 1
# ['Old El Paso™ taco seasoning mix'] 6
# ['sliced olives'] 7
# ['roasted unsalted cashews'] 2
# ['chopped leaves'] 7
# ['Belgian endive'] 22
# ['shell pasta'] 6
# ['Pace Chunky Salsa'] 6
# ...
# ['seltzer'] 1
# ['Smart Balance Cooking Spray'] 1
# ['boar'] 2
# ['bean thread vermicelli'] 1
# ['chocolate frosting'] 1
# ['marmalade'] 3
# ['guava paste'] 1
# ['asti spumante'] 1
# ['konnyaku'] 2
# ['english breakfast tea leaves'] 1
# ['nama shoyu'] 1
# ['chestnut purée'] 1
# ['meal'] 1
# ['organic vegetable stock'] 1
# ['sub rolls'] 2
# ['ready-made pie crusts'] 1
# ['pasilla chile pepper'] 2
# ['canning salt'] 2
# ['almond syrup'] 1
# ['jamon serrano'] 1
# ['brown chicken stock'] 1
# ['salted fish'] 1
# ['asian chile paste'] 2
# ['gluten-free bread'] 1
# ['instant oats'] 1
# ['Progresso™ Chicken Broth'] 1
# ['poppadoms'] 1
# ['chunky tomato sauce'] 2
# ['smoked almonds'] 1
# ['low sodium tomato'] 1
# ['roasting hen'] 1
# ['sago'] 3
# ['chicken breast tenderloins'] 2
# ['blackberry brandy'] 1
# ['boneless salmon fillets'] 2
# ['suckling pig'] 1
# ['33% less sodium cooked deli ham'] 1
# ['whole wheat crackers'] 1
# ['instant couscous'] 2
# ['raspberry lambic'] 1
# ['white baking bar'] 1
# ['bittersweet baking chocolate'] 1
# ['Ro-Tel Diced Tomatoes & Green Chilies'] 1
# ['moonshine'] 1
# ['low sodium vegetable stock'] 2
# ['low fat part skim ricotta chees'] 1
# ['kochu chang'] 1
# ['reduced-fat cheese'] 2
# ['mango juice'] 2
# ['blanco chees queso'] 1
# ['red sockeye'] 1
# ['low-fat turkey kielbasa'] 1
# ['iceberg'] 2
# ['legumes'] 1
# ['olive tapenade'] 3
# ['Mezzetta Sliced Greek Kalamata Olives'] 1
# ['any'] 1
# ['chop green chilies', ' undrain'] 1
# ['winter melon'] 2
# ['extra virgin coconut oil'] 2
# ['low sodium beef bouillon granules'] 1
# ['wheat cereal'] 1
# ['peapods'] 1
# ['hoja santa leaves'] 1
# ['reduced sodium italian style stewed tomatoes'] 1
# ['raspberry sauce'] 2
# ['matsutake mushrooms'] 1
# ['Soy Vay® Hoisin Garlic Marinade & Sauce'] 1
# ['cold-smoked salmon'] 1
# ['scape pesto'] 1
# ['whole wheat spaghetti noodles'] 1
# ['wild garlic'] 1
# ['sauvignon blanc'] 2
# ['carpaccio'] 1
# ['riso'] 1
# ['sliced leeks'] 3
# ['low sodium crushed tomatoes'] 2
# ['shelled shrimp'] 1
# ['dried coconut flakes'] 2
# ['mixed frozen seafood'] 1
# ['baby artichokes'] 1
# ['organic low sodium chicken broth'] 1
# ['cajun remoulade'] 1
# ['hake fillets'] 1
# ['paratha'] 1
# ['azuki bean'] 1
# ['besan (flour)'] 2
# ['nonfat italian dressing'] 1
# ['angus'] 1
# ['Knorr® Pasta Sides™ - Chicken flavor'] 1
# ['low-fat canned coconut milk'] 1
# ['pilsner'] 1
# ['lavender flowers'] 1
# ['duck bones'] 1
# ['schmaltz'] 3
# ['thousand island dressing'] 2
# ['bird pepper'] 1
# ['Kraft Mayonnaise'] 1
# ['whole wheat pita pockets'] 1
# ['alfalfa sprouts'] 3
# ['muscadine grapes'] 2
# ['pot stickers'] 1
# ['head cauliflower'] 2
# ['italian vinaigrette'] 1
# ['branca menta'] 1
# ['Kraft Extra Sharp Cheddar Cheese'] 1
# ['Rice Krispies Cereal'] 1
# ['Jonshonville® Cajun Style Chicken Sausage'] 1
# ['edamame beans'] 2
# ['kinchay'] 2
# ['frozen cherries'] 1
# ['dipping chocolate'] 1
# ['ground nuts'] 1
# ['creme de cacao'] 1
# ['filé'] 1
# ['london broil'] 1
# ['garlic shoots'] 2
# ['gluten-free pasta'] 1
# ['sugar cubes'] 2
# ['cubed pancetta'] 1
# ['Gebhardt Chili Powder'] 1
# ['Pure Wesson Vegetable Oil'] 1
# ['lean minced lamb'] 1
# ['Manzanilla olives'] 1
# ['dri basil leaves', ' crush'] 2
# ['flageolet'] 1
# ['vodka sauce'] 1
# ['pareve margarine'] 1
# ['pomelo'] 1
# ['Thai chili garlic sauce'] 1
# ['meat cuts'] 1
# ['sherbet'] 1
# ['quick yeast'] 1
# ['vanilla powder'] 1
# ['frozen popcorn chicken'] 1
# ['split yellow lentils'] 1
# ['frozen mashed potatoes'] 1
# ['bread machine yeast'] 2
# ['val'] 1
# ['Bisquick Original All-Purpose Baking Mix'] 1
# ['dried rigatoni'] 1
# ['coarse semolina'] 2
# ['low-fat sharp cheddar cheese'] 1
# ['apple brandy'] 1
# ['lecithin'] 1
# ['shrimp small uncook'] 1
# ['lipton tea bags'] 2
# ['nondairy whipped topping'] 1
# ['ground pork sausage'] 2
# ['fillet steaks'] 1
# ['durum wheat flour'] 1
# ['Old El Paso Green Chiles'] 1
# ['porter'] 1
# ['semi pearled farro'] 1
# ['chile puree'] 1
# ['Truvía® Baking Blend'] 1
# ['chrysanthemum'] 1
# ['salted anchovies'] 1
# ['white bread crumbs'] 1
# ['2 1/2 to 3 lb. chicken', ' cut into serving pieces'] 1
# ['regular or convert rice'] 2
# ['bacon', ' crisp-cooked and crumbled'] 2
# ['Pepperidge Farm Puff Pastry Sheets'] 1
# ['meringue powder'] 1
# ['sichuan peppercorn oil'] 1
# ['ramen noodles seasoning'] 1
# ['fudge cake mix'] 1
# ['fresh curry'] 1
# ['fat-free croutons'] 1
# ['pita loaves'] 3
# ['dried beans'] 2
# ['truffle salt'] 1
# ['broiler chicken'] 1
# ['hot cocoa mix'] 1
# ['Pale Ale'] 1
# ['pork sirloin'] 2
# ['coleslaw dressing'] 1
# ['Everglades Seasoning'] 1
# ['frozen ravioli'] 1
# ['pearl tapioca'] 1
# ['reduced sugar orange marmalade'] 1
# ['chinese plum sauce'] 1
# ['McCormick Ground Cumin'] 1
# ['chile piquin'] 1
# ['pisco brandy'] 1
# ['cornbread crumbs'] 1
# ['cooked beetroot'] 1
# ['creamed horseradish'] 2
# ['roasted garlic oil'] 1
# ['baby goat'] 1
# ['cheese curds'] 1
# ['Castelvetrano olives'] 1
# ['sweet bean sauce'] 2
# ['fermented bean paste'] 2
# ['natural low-fat yogurt'] 1
# ['cactus'] 1
# ['marshmallows'] 2
# ['pork bouillon cube'] 1
# ['shredded nori'] 1
# ['boneless steak'] 1
# ['Reblochon'] 1
# ['queso panela'] 3
# ['farina'] 1
# ['fat-free shredded cheddar cheese'] 2
# ['sazon seasoning'] 3
# ['sun dried tomato dressing'] 1
# ['apple slice'] 1
# ['sago pearls'] 1
# ['cucuzza'] 1
# ['flavored tortilla chips'] 2
# ['frozen onion rings'] 1
# ['currant jelly'] 1
# ['tart shells'] 3
# ['self raising flour'] 3
# ['pepper cheese'] 1
# ['sunflower kernels'] 1
# ['pork sirloin roast'] 1
# ['fat free ice cream'] 1
# ['verjuice'] 1
# ['nonfat mozzarella cheese'] 1
# ['unhulled sesame seeds'] 1
# ['Domino Light Brown Sugar'] 2
# ['salad leaves'] 1
# ['lamb leg steaks'] 1
# ['bhaji'] 1
# ['sirloin tip steak'] 1
# ['black radish'] 1
# ['white zinfandel'] 1
# ['sturgeon'] 1
# ['rustic rub'] 1
# ['sweet and sour mix'] 2
# ['Dole Seven Lettuces'] 1
# ['Bengali 5 Spice'] 1
# ['other'] 1
# ['Nakano Seasoned Rice Vinegar'] 1
# ['top loin steaks'] 1
# ['chinese leaf'] 1
# ['tupelo honey'] 1
# ['soybean oil'] 1
# ['canned chipotles'] 1
# ['butterscotch sauce'] 1
# ['beet juice'] 1
# ['Pillsbury™ classic pizza crust'] 1
# ['ducklings'] 1
# ['muscadet'] 1
# ['beurre manié'] 2
# ['buffalo mozarella'] 2
# ['asian dressing'] 1
# ['strawberry compote'] 1
# ['chocolate milk mix'] 1
# ['tatsoi'] 1
# ['tuong'] 1
# ['reduced fat reduced sodium cream of mushroom soup'] 1
# ['reduced sodium chicken flavor stuffing mix'] 1
# ['rub seasoning'] 1
# ['gluten free barbecue sauce'] 1
# ['sourdough starter'] 4
# ['malt powder'] 1
# ['topping'] 1
# ['filling'] 1
# ['beef boneless meat stew'] 1
# ['creamer potatoes'] 1
# ['turkey breast deli meat'] 2
# ['yucca'] 1
# ['vegan sour cream'] 2
# ['rice bran'] 1
# ['low-fat firm silken tofu'] 1
# ['bacardi'] 1
# ['wheatberries'] 1
# ['lo bok'] 1
# ['spring rolls'] 2
# ['diced mushrooms'] 1
# ['guinea hens'] 1
# ['organic coconut oil'] 1
# ['t-bone steak'] 1
# ['pie crust mix'] 1
# ['dried bonito'] 1
# ['salt free cajun creole seasoning'] 1
# ['black cherries'] 1
# ['ginkgo nut'] 1
# ['Kim Crawford Sauvignon Blanc'] 1
# ['Old Bay Blackened Seasoning'] 1
# ['ahi tuna steaks'] 1
# ['cream cheese spread'] 2
# ['nonfat frozen yogurt'] 1
# ['porcini powder'] 2
# ['montreal steak seasoning'] 1
# ['arak'] 1
# ['cream cheese lowfat'] 2
# ['bean dip'] 1
# ['fructose'] 1
# ['low fat cream'] 1
# ['italian loaf'] 3
# ['frozen crabmeat', ' thaw and drain'] 1
# ['tubettini'] 1
# ['cointreau liqueur'] 2
# ['Amarena cherries'] 1
# ['slider rolls'] 1
# ['reduced fat chunky peanut butter'] 1
# ['sesame butter'] 1
# ['sangria'] 1
# ['jerk seasoning mix'] 1
# ['fresh poblano pepper'] 1
# ['foie gras terrine'] 1
# ['verjus'] 1
# ['crouton italian season'] 1
# ['irish oats'] 1
# ['Zatarains Creole Seasoning'] 1
# ['compote'] 1
# ['herring fillets'] 1
# ['jamaican curry powder'] 1
# ['baby kale'] 1
# ['creamed coconut'] 1
# ['candied ginger'] 2
# ['Knudsen Sour Cream'] 1
# ['cream powder'] 1
# ['process cheese spread'] 2
# ['raspberry puree'] 1
# ['pineapple syrup'] 1
# ['american cheese food'] 1
# ['vanilla cake mix'] 1
# ['Kikkoman Less Sodium Soy Sauce'] 1
# ['refrigerated bread dough'] 1
# ['Kikkoman Oyster Sauce'] 2
# ['prepared pie crusts'] 3
# ['meat glaze'] 1
# ['italian rolls'] 1
# ['shoulder lamb chops'] 2
# ['tomato sauce low sodium'] 1
# ['McCormick Taco Seasoning'] 1
# ['peeled prawns'] 2
# ['water chestnut powder'] 1
# ['chioggia'] 1
# ['flat cut'] 1
# ['KRAFT Zesty Lime Vinaigrette Dressing'] 1
# ['KRAFT Shredded Colby & Monterey Jack Cheese'] 1
# ['brewed tea'] 1
# ['reduced sodium smoked ham'] 1
# ['veal medallions'] 1
# ['new mexico red chile powder'] 1
# ['boquerones'] 1
# ['sweet white wine'] 1
# ['elderflower cordial'] 1
# ['oyster liquor'] 1
# ['matzo cake meal'] 1
# ['lemon cake mix'] 1
# ['strawberry ice cream'] 2
# ['chinese ginger'] 1
# ['pizza seasoning'] 1
# ['lasagna sheets'] 1
# ['rum raisin ice cream'] 1
# ['pippin apples'] 1
# ['pandan essence'] 1
# ['seasoning rub'] 1
# ['tricolor quinoa'] 1
# ['liquid sweetener'] 1
# ['eye of round steak'] 2
# ['shoulder roast'] 1
# ['country gravy'] 1
# ['edible gold leaf'] 1
# ['flax egg'] 1
# ['reduced sodium fat free chicken broth'] 2
# ['chocolate liqueur'] 1
# ['cherrystone clams'] 1
# ['honey dijon mustard'] 1
# ['cured pork'] 1
# ['black trumpet mushrooms'] 1
# ['straight bourbon whiskey'] 1
# ['condensed reduced fat reduced sodium tomato soup'] 2
# ['condensed cream'] 1
# ['anise powder'] 1
# ['low-fat plain greek yogurt'] 1
# ['italian seasoning mix'] 2
# ['bone marrow'] 1
# ['swiss'] 1
# ['spot prawns'] 1
# ['snow crab'] 1
# ['barilla piccolini mini'] 1
# ['salmon sashimi'] 1
# ['red mullet'] 1
# ['grape vine leaves'] 1
# ['brown butter'] 1
# ['cold meatloaf'] 1
# ['cold cut'] 1
# ['beef marrow'] 1
# ['peanut butter chips'] 1
# ['Diamond Crystal® Kosher Salt'] 1
# ['TACO BELL® Thick & Chunky Mild Salsa'] 1
# ['White Lily Flour'] 1
# ['gray salt'] 1
# ['squash seeds'] 1
# ['praline'] 1
# ['hungarian hot paprika'] 1
# ['pita wraps'] 1
# ['chuka soba noodles'] 1
# ['mesquite seasoning'] 2
# ['andouille turkey sausages'] 2
# ['cranberry juice cocktail'] 1
# ['Nido Milk Powder'] 1
# ['liverwurst'] 1
# ['french style sandwich rolls'] 1
# ['Kitchen Bouquet'] 1
# ['do chua'] 1
# ['cannelloni shells'] 1
# ['shanghai bok choy'] 1
# ['mian'] 1
# ['Lea & Perrins Worcestershire Sauce'] 1
# ['eggnog'] 1
# ['old-fashioned oatmeal'] 2
# ['Pillsbury Pie Crusts'] 1
# ['brown rice penne'] 1
# ['mahimahi fillet'] 1
# ['banana squash'] 1
# ['dark rye flour'] 1
# ['brown sauce'] 1
# ['cream of potato soup'] 1
# ['guanabana'] 1
# ['Knorr Onion Minicubes'] 3
# ['sack'] 1
# ['celery powder'] 1
# ['mellow white miso'] 1
# ['low fat coleslaw dressing'] 1
# ['hijiki'] 1
# ['farofa'] 1
# ['cannelloni'] 1
# ['chowchow'] 1
# ['Hogue Cabernet Sauvignon'] 1
# ['won ton skins'] 1
# ['chinese winter melon'] 1
# ['beef carpaccio'] 1
# ['whole wheat bread slices'] 1
# ['ground peanut'] 1
# ['frozen brussels sprouts'] 1
# ['homemade beef stock'] 2
# ['paprika paste'] 1
# ['gnocchetti sardi'] 1
# ['Sargento® Artisan Blends® Shredded Parmesan Cheese'] 1
# ['jerk rub seasoning'] 1
# ['small pearl tapioca'] 1
# ['rice mix'] 1
# ['color food orang'] 3
# ['non fat chicken stock'] 1
# ['heirloom squash'] 1
# ['Bertolli Tomato & Basil Sauce'] 1
# ['scrod fillets'] 1
# ['small shells'] 1
# ['sunchokes'] 2
# ["Eggland's Best® eggs"] 1
# ['speck'] 1
# ['regular sour cream'] 1
# ['evaporated cane juice'] 1
# ['pork heart'] 1
# ['miswa'] 1
# ['blood'] 1
# ['brown beech mushrooms'] 1
# ['framboise liqueur'] 1
# ['frozen sweetened raspberries'] 1
# ['fresh ham'] 1
# ['pancetta slices'] 2
# ['beluga lentil'] 1
# ['goat s milk cheese'] 1
# ['barolo'] 1
# ['Herdez Salsa'] 1
# ['tomato chutney'] 1
# ['light whipping cream'] 1
# ['poolish'] 1
# ['Wish-Bone® Robusto Italian Dressing'] 1
# ['meat drippings'] 1
# ['frozen seafood'] 1
# ['gluten-free tamari sauce'] 1
# ['gluten-free oyster sauce'] 1
# ['light lager'] 1
# ['kangkong'] 1
# ['aged cheddar cheese'] 2
# ['langoustines'] 1
# ['valencia rice'] 1
# ['prosciutto fat'] 1
# ['vanilla bean seeds'] 1
# ['pummelo'] 1
# ['Lipton Lemon Iced Tea Mix'] 1
# ['pollock'] 1
# ['whole wheat rotini'] 2
# ['cracked wheat'] 1
# ['organic unsalted butter'] 1
# ["devil's food cake mix"] 1
# ['dip mix'] 1
# ['spinach tortilla'] 1
# ['reduced sugar ketchup'] 1
# ['nonfat milk powder'] 1
# ['dried neem leaves'] 1
# ['glucose'] 1
# ['dried shallots'] 1
# ['english breakfast tea'] 1
# ['german mustard'] 1
# ['Johnsonville® Mild Italian Ground Sausage'] 1
# ['diced bacon'] 1
# ['crushed peppercorn'] 1
# ['tarragon vinegar'] 2
# ['custard'] 1
# ['arhar'] 1
# ['borlotti'] 1
# ['mole paste'] 1
# ['savoy spinach'] 1
# ['roasted pepitas'] 1
# ['anise oil'] 1
# ['stevia powder'] 1
# ['pork back ribs'] 2
# ['low-fat vanilla wafers'] 1
# ['whole turkey'] 1
# ['canned beans'] 1
# ['low fat shred cheddar chees sharp varieti'] 1
# ['chinese radish'] 1
# ['Spice Islands Garlic Salt'] 1
# ['Spice Islands Ground Cumin Seed'] 1
# ['cortland apples'] 1
# ['king crab'] 1
# ['madeleine'] 1
# ['cooked long-grain brown rice'] 1
# ['KRAFT Mexican Style 2% Milk Finely Shredded Four Cheese'] 1
# ['TACO BELL® HOME ORIGINALS® Taco Seasoning Mix'] 1
# ['shark'] 1
# ['raspberry sherbet'] 1
# ['peach sorbet'] 1
# ['candy bar'] 1
# ['manicotti'] 1
# ['george dickel'] 1
# ['Hidden Valley® Original Ranch® Light Dressing'] 2
# ['baked pita chips'] 1
# ['spicy mayonnaise'] 1
# ['coconut butter'] 2
# ['cold coffee'] 1
# ['panela'] 1
# ['Green Giant Whole Kernel Sweet Corn'] 1
# ['graham flour'] 1
# ['oat bran'] 1
# ['corn bread crumbs'] 1
# ['whey'] 1
# ['boneless beef rib eye steaks'] 1
# ['cubed meat'] 1
# ['greek seasoning mix'] 1
# ['snip fresh dill'] 1
# ['bermuda onion'] 1
# ['hoja santa'] 1
# ['tuna', ' drain and flake'] 1
# ['rum extract'] 1
# ['tempura batter'] 1
# ['pumpkin seed mole'] 1
# ['swanson chicken stock'] 1
# ['whole wheat sourdough bread'] 1
# ['hot pepperoni'] 1
# ['citric acid powder'] 1
# ['cooki vanilla wafer'] 1
# ['honeycomb tripe'] 1
# ['bertolli vineyard premium collect marinara with burgundi wine sauc'] 1
# ['oil packed dried tomatoes'] 2
# ['knorr reduc sodium chicken flavor bouillon cube'] 1
# ['puff pastry cups'] 1
# ['wensleydale'] 1
# ['whole wheat angel hair pasta'] 2
# ['blanco tequila'] 1
# ['Doritos Tortilla Chips'] 1
# ['Cinnamon Toast Crunch Cereal'] 1
# ['carrot juice'] 1
# ['Breakstone’s Sour Cream'] 1
# ['winesap'] 1
# ['friselle'] 1
# ['aquavit'] 1
# ['sato imo'] 1
# ['Knorr Beef Stock Cubes'] 1
# ['shredded lowfat monterey jack cheese'] 1
# ['shredded low-fat cheddar cheese'] 1
# ['huckleberries'] 1
# ['grated parmesan romano'] 1
# ['carp'] 2
# ['greek-style vinaigrette'] 1
# ['cooked deli ham'] 1
# ['potato starch flour'] 1
# ['lotus leaves'] 1
# ['sazon goya with coriander and annatto'] 1
# ['crosswise'] 1
# ['smoked haddock fillet'] 1
# ['skinless snapper fillets'] 1
# ['sliced kalamata olives'] 1
# ['eel'] 1
# ['pike'] 1
# ['hot fudge topping'] 1
# ['matzos'] 1
# ['hot italian turkey sausage'] 1
# ['baby tatsoi'] 1
# ['young nettle'] 1
# ['toffee bits'] 1
# ['no salt added canned tomatoes'] 1
# ['cinnamon hot candy'] 1
# ['chili con carne'] 1
# ['imitation seafood'] 1
# ['soft margarine'] 1
# ['dark chocolate cocoa powder'] 1
# ['granular sucrolose sweetener'] 1
# ['Italian turkey sausage links'] 1
# ['Japanese Mayonnaise'] 1
# ['Holland House White Wine Vinegar'] 1
# ['frankfurters'] 1
# ['raclette'] 1
# ['Ragu Traditional Sauce'] 1
# ['soy-based liquid seasoning'] 1
# ['reduced sodium chicken bouillon granules'] 1
# ['yogurt low fat'] 1
# ['ganache'] 1
# ['boneless duck breast halves'] 1
# ['Classico Pasta Sauce'] 1
# ['tortelloni'] 1
# ['rice milk'] 1
# ['dried lavender flowers'] 1
# ['ground asafetida'] 1
# ['sandwich wraps'] 1
# ['salt free chili powder'] 1
# ['tofu sour cream'] 1
# ['capocollo'] 2
# ['spicy salami'] 1
# ['citric acid'] 1
# ['silver dragees'] 1
# ['Honeysuckle White® Hot Italian Turkey Sausage Links'] 1
# ['sashimi grade tuna'] 1
# ['cumberland sausage'] 1
# ['cocktail pumpernickel bread'] 1
# ['chunky tomatoes'] 1
# ['boysenberries'] 1
# ['cherry vanilla ice cream'] 1
# ['bone-in ribeye steak'] 1
# ['frozen lemonade concentrate', ' thawed and undiluted'] 1
# ['flowering chinese chives'] 1
# ['oloroso sherry'] 1
# ['praline topping'] 1
# ['crescent dinner rolls'] 1
# ['Barilla Plus Pasta'] 1
# ['turkey giblet stock'] 1
# ['light chicken stock'] 1
# ['tortellini', ' cook and drain'] 1
# ['conchiglie'] 1
# ['gluten-free spaghetti'] 1
# ['knorr pasta side   cheesi cheddar'] 1
# ['whole grain baguette'] 1
# ['whole wheat peasant bread'] 1
# ['sliced fresh fruit'] 1
# ['chees mozzarella stick'] 1
# ['au jus gravy mix'] 1
# ['ranch-style seasoning'] 1
# ['ketjap'] 1
# ['chocolate flavored liqueur'] 1
# ['swordfish'] 1
# ['tongue'] 1
# ['Daiya'] 1
# ['malt syrup'] 1
# ['curry mix'] 1
# ['Challenge Butter'] 1
# ['orange glaze'] 1
# ['cholesterol free egg substitute'] 1
# ['Lipton® Iced Tea Brew Family Size Tea Bags'] 1
# ['Hidden Valley® Greek Yogurt Original Ranch® Dip Mix'] 1
# ['vegetable gumbo'] 1
# ['lop chong'] 1
# ['tomato garlic pasta sauce'] 1
# ['peaches in light syrup'] 1
# ['crushed cheese crackers'] 1
# ['citrus fruit'] 1

# %%
cpt_answers = []
for data in tqdm(val_cpt_q[0:10]):
#     print(data)
    weight_dict = {}
    for node in data:
        for adv, w in G.adj[node].items():
            if adv in weight_dict.keys():
#                 print(freq_dict[adv])
                weight_dict[adv] += w['weight'] / (freq_dict[adv] ** 1/2)
            else:
                weight_dict[adv] = w['weight'] / (freq_dict[adv] ** 1/2)
    for node in data:
        if node in weight_dict.keys():
            del weight_dict[node]
    
    weight_dict = sorted(weight_dict.items(), key=(lambda x: x[1]), reverse=True)
    
#     print(weight_dict)

    cpt_answers.append(weight_dict[0][0])
# Out:
# 100%|███████████████████████████████████████████| 10/10 [00:00<00:00, 35.43it/s]
# [('2944', 6.0), ('1995', 6.0), ('4493', 6.0), ('6147', 6.0), ('2537', 5.0), ('3126', 4.0), ('5947', 4.0), ('1331', 4.0), ('4558', 4.0), ('4837', 4.0), ('388', 4.0), ('1638', 4.0), ('5623', 4.0), ('2619', 4.0), ('2037', 4.0), ('153', 4.0), ('1262', 4.0), ('1647', 4.0), ('6331', 4.0), ('4371', 4.0), ('1829', 4.0), ('5911', 4.0), ('740', 4.0), ('165', 4.0), ('1369', 4.0), ('152', 4.0), ('6706', 4.0), ('6374', 4.0), ('4851', 4.0), ('4265', 4.0), ('4384', 4.0), ('5197', 4.0), ('1728', 4.0), ('3890', 4.0), ('3267', 4.0), ('369', 4.0), ('4169', 4.0), ('4348', 4.0), ('2336', 4.0), ('967', 4.0), ('1227', 4.0), ('3218', 4.0), ('3505', 3.333333333333333), ('2231', 3.2), ('4025', 3.0), ('29', 3.0), ('1418', 3.0), ('4137', 
print(acc / len(cpt_answers) * 100)
print(1 / len(cpt_answers) * 100)
# Out:
# 0.0382262996941896
# 0.012742099898063202

# %% [markdown]
# # Classification Task

# %%
train_data = {}
for data in trains:
    cuis = data[-1]
    if cuis in train_data.keys():
        train_data[cuis].append(data[0:-1])
    else:
        train_data[cuis] = []
        
print(len(train_data.keys()))

for cuisine in train_data.keys():
    np_ing = np.zeros((len(nodes), len(train_data[cuisine])))
    for i in range(len(train_data[cuisine])):
        for ing in train_data[cuisine][i]:
            np_ing[int(ing)][i] = 1
    train_data[cuisine] = np_ing

for cuisine in train_data.keys():
    print(cuisine, train_data[cuisine].shape[1])
# Out:
# 20
# greek 713
# filipino 451
# indian 1747
# jamaican 279
# spanish 589
# italian 4677
# mexican 3835
# vietnamese 486
# thai 902
# southern_us 2514
# chinese 1598
# cajun_creole 919
# brazilian 282
# french 1542
# japanese 839
# irish 403
# moroccan 495
# korean 473
# british 484
# russian 299

# %%
train_matrix = np.zeros((len(nodes), len(trains)))
print(train_matrix.shape)
for i in range(len(trains)):
    for
# Out:
# (6714, 23547)

# %%
def similarity(x1, x2):
    return np.dot(x1, x2)

# %%
for i in range(1,11):
    print(similarity(train_data['greek'][:,0], train_data['greek'][:,i]))
# Out:
# 0.0
# 0.0
# 2.0
# 1.0
# 1.0
# 0.0
# 0.0
# 1.0
# 1.0
# 2.0

# %%
# classification validation
answers = []
for ings in tqdm(val_cls_q[:1000]):
#     print(ings)
    np_q = np.zeros((len(nodes),))
    for ing in ings:
        np_q[int(ing)] = 1
    
    max_sim = 0
    max_cuisine = ''
    for cuisine in train_data.keys():
        sim = 0
        for i in range(train_data[cuisine].shape[1]):
            sim += similarity(np_q, train_data[cuisine][:,i])
        sim  = sim / train_data[cuisine].shape[1]
#         print(cuisine, sim)
        if sim >= max_sim:
            max_sim = sim
            max_cuisine = cuisine
    
    answers.append(max_cuisine)
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [19:04<00:00,  1.14s/it]

# %%
acc = 0
for i in range(1000):
    if answers[i] == val_cls_a[i][0]:
        acc += 1
print(acc)
# Out:
# 344

# %%
print(val_cls_a)
# Out:
# [['japanese'], ['french'], ['filipino'], ['brazilian'], ['italian'], ['southern_us'], ['italian'], ['filipino'], ['japanese'], ['vietnamese'], ['spanish'], ['mexican'], ['indian'], ['mexican'], ['southern_us'], ['southern_us'], ['italian'], ['korean'], ['indian'], ['mexican'], ['vietnamese'], ['italian'], ['vietnamese'], ['italian'], ['southern_us'], ['mexican'], ['italian'], ['italian'], ['italian'], ['italian'], ['spanish'], ['southern_us'], ['indian'], ['mexican'], ['jamaican'], ['italian'], ['southern_us'], ['french'], ['italian'], ['japanese'], ['italian'], ['mexican'], ['french'], ['mexican'], ['japanese'], ['jamaican'], ['mexican'], ['vietnamese'], ['japanese'], ['cajun_creole'], ['greek'], ['mexican'], ['southern_us'], ['mexican'], ['mexican'], ['chinese'], ['southern_us'], ['moroccan'], ['mexican'], ['italian'], ['chinese'], ['greek'], ['southern_us'], ['brazilian'], ['japanese'], ['chinese'], ['